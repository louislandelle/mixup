# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt

# %%
import util
import exp_models
import lambdas

# %%
# Reproducibility
SEED = 2019

np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
trainset, testset = util.get_sets("CIFAR10")
model_getter=exp_models.resnet18
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainloader, N_BATCHES_TRAIN = util.get_loader(trainset, shuffle=True)
testloader, N_BATCHES_TEST = util.get_loader(testset, shuffle=False)
util.show_loader(trainloader)

# %%
#LAMBDAS = lambdas.invpow(4, 4)
LAMBDAS = lambdas.sweetspot(5)
LAMBDAS
# Out:
# [array([0.75      , 0.1875    , 0.046875  , 0.01171875, 0.00390625])]

# %%
RESULTS_FNAME = "deleteme0"
with open("results/"+RESULTS_FNAME, "w"):pass
test_accs, train_losses, val_losses, images_mx, ys, perms = util.perform_experiment(
    trainloader,
    testloader,
    lambdas=LAMBDAS,
    results_fname=RESULTS_FNAME,
    N_BATCHES_TRAIN=N_BATCHES_TRAIN,
    model_getter=model_getter,
    n_epochs=5,
    n_batches=100
)
# Out:
# Saving results in deleteme0
# Trying lambda= [0.75       0.1875     0.046875   0.01171875 0.00390625]
# Performing n-mixup with N-mix: 5
# Epoch[1/20]
# train loss:2.3268 Epoch[1/20] Batch[0/500]
# val loss:1.9142 Epoch[1/20]
# val acc:30.0000 Epoch[1/20]
# Epoch[2/20]
# train loss:2.1082 Epoch[2/20] Batch[0/500]
# val loss:1.8522 Epoch[2/20]
# val acc:33.0000 Epoch[2/20]
# Epoch[3/20]
# train loss:2.0199 Epoch[3/20] Batch[0/500]
# val loss:1.7065 Epoch[3/20]
# val acc:36.0000 Epoch[3/20]
# Epoch[4/20]
# train loss:1.9178 Epoch[4/20] Batch[0/500]
# val loss:1.5596 Epoch[4/20]
# val acc:49.0000 Epoch[4/20]
# Epoch[5/20]
# train loss:2.0618 Epoch[5/20] Batch[0/500]
# val loss:1.5389 Epoch[5/20]
# val acc:46.0000 Epoch[5/20]
# Epoch[6/20]
# train loss:1.9708 Epoch[6/20] Batch[0/500]
# val loss:1.5642 Epoch[6/20]
# val acc:48.0000 Epoch[6/20]
# Epoch[7/20]
# train loss:1.9098 Epoch[7/20] Batch[0/500]
# val loss:1.4276 Epoch[7/20]
# val acc:52.0000 Epoch[7/20]
# Epoch[8/20]
# train loss:1.8390 Epoch[8/20] Batch[0/500]
# val loss:1.3770 Epoch[8/20]
# val acc:52.0000 Epoch[8/20]
# Epoch[9/20]
# train loss:1.9251 Epoch[9/20] Batch[0/500]
# val loss:1.3894 Epoch[9/20]
# val acc:52.0000 Epoch[9/20]
# Epoch[10/20]
# train loss:1.6834 Epoch[10/20] Batch[0/500]
# val loss:1.4285 Epoch[10/20]
# val acc:44.0000 Epoch[10/20]
# Epoch[11/20]
# train loss:1.8776 Epoch[11/20] Batch[0/500]
# val loss:1.3221 Epoch[11/20]
# val acc:55.0000 Epoch[11/20]
# Epoch[12/20]
# train loss:1.6583 Epoch[12/20] Batch[0/500]
# val loss:1.3430 Epoch[12/20]
# val acc:49.0000 Epoch[12/20]
# Epoch[13/20]
# train loss:1.6913 Epoch[13/20] Batch[0/500]
# val loss:1.3096 Epoch[13/20]
# val acc:61.0000 Epoch[13/20]
# Epoch[14/20]
# train loss:1.7711 Epoch[14/20] Batch[0/500]
# val loss:1.3911 Epoch[14/20]
# val acc:49.0000 Epoch[14/20]
# Epoch[15/20]
# train loss:1.7895 Epoch[15/20] Batch[0/500]
# val loss:1.2229 Epoch[15/20]
# val acc:60.0000 Epoch[15/20]
# Epoch[16/20]
# train loss:1.8359 Epoch[16/20] Batch[0/500]
# val loss:1.2947 Epoch[16/20]
# val acc:56.0000 Epoch[16/20]
# Epoch[17/20]
# train loss:1.6469 Epoch[17/20] Batch[0/500]
# val loss:1.1895 Epoch[17/20]
# val acc:69.0000 Epoch[17/20]
# Epoch[18/20]
# train loss:1.7368 Epoch[18/20] Batch[0/500]
# val loss:1.2227 Epoch[18/20]
# val acc:61.0000 Epoch[18/20]
# Epoch[19/20]
# train loss:1.6207 Epoch[19/20] Batch[0/500]
# val loss:1.1962 Epoch[19/20]
# val acc:60.0000 Epoch[19/20]
# Epoch[20/20]
# train loss:1.5680 Epoch[20/20] Batch[0/500]
# val loss:1.0518 Epoch[20/20]
# val acc:70.0000 Epoch[20/20]
# Test Accuracy of the model on the test images: 54.85 %
# Saving results in deleteme1
# Trying lambda= [0.75       0.1875     0.046875   0.01171875 0.00390625]
# Performing n-mixup with N-mix: 5
# Epoch[1/20]
# train loss:2.3410 Epoch[1/20] Batch[0/500]
# val loss:1.7988 Epoch[1/20]
# val acc:34.0000 Epoch[1/20]
# Epoch[2/20]
# train loss:2.1717 Epoch[2/20] Batch[0/500]
# val loss:1.7829 Epoch[2/20]
# val acc:37.0000 Epoch[2/20]
# Epoch[3/20]
# train loss:2.0479 Epoch[3/20] Batch[0/500]
# val loss:1.6720 Epoch[3/20]
# val acc:40.0000 Epoch[3/20]
# Epoch[4/20]
# train loss:1.9807 Epoch[4/20] Batch[0/500]
# val loss:1.6528 Epoch[4/20]
# val acc:38.0000 Epoch[4/20]
# Epoch[5/20]
# train loss:1.9309 Epoch[5/20] Batch[0/500]
# val loss:1.5666 Epoch[5/20]
# val acc:45.0000 Epoch[5/20]
# Epoch[6/20]
# train loss:1.9036 Epoch[6/20] Batch[0/500]
# val loss:1.6174 Epoch[6/20]
# val acc:41.0000 Epoch[6/20]
# Epoch[7/20]
# train loss:1.9736 Epoch[7/20] Batch[0/500]
# val loss:1.4826 Epoch[7/20]
# val acc:51.0000 Epoch[7/20]
# Epoch[8/20]
# train loss:1.8661 Epoch[8/20] Batch[0/500]
# val loss:1.4500 Epoch[8/20]
# val acc:48.0000 Epoch[8/20]
# Epoch[9/20]
# train loss:1.9141 Epoch[9/20] Batch[0/500]
# val loss:1.4671 Epoch[9/20]
# val acc:51.0000 Epoch[9/20]
# Epoch[10/20]
# train loss:1.7847 Epoch[10/20] Batch[0/500]
# val loss:1.3671 Epoch[10/20]
# val acc:53.0000 Epoch[10/20]
# Epoch[11/20]
# train loss:1.8552 Epoch[11/20] Batch[0/500]
# val loss:1.3985 Epoch[11/20]
# val acc:47.0000 Epoch[11/20]
# Epoch[12/20]
# train loss:1.7728 Epoch[12/20] Batch[0/500]
# val loss:1.4190 Epoch[12/20]
# val acc:45.0000 Epoch[12/20]
# Epoch[13/20]
# train loss:1.7642 Epoch[13/20] Batch[0/500]
# val loss:1.2856 Epoch[13/20]
# val acc:54.0000 Epoch[13/20]
# Epoch[14/20]
# train loss:1.7211 Epoch[14/20] Batch[0/500]
# val loss:1.2904 Epoch[14/20]
# val acc:55.0000 Epoch[14/20]
# Epoch[15/20]
# train loss:1.7637 Epoch[15/20] Batch[0/500]
# val loss:1.2799 Epoch[15/20]
# val acc:61.0000 Epoch[15/20]
# Epoch[16/20]
# train loss:1.6658 Epoch[16/20] Batch[0/500]
# val loss:1.2315 Epoch[16/20]
# val acc:55.0000 Epoch[16/20]
# Epoch[17/20]
# train loss:1.6868 Epoch[17/20] Batch[0/500]
# val loss:1.2013 Epoch[17/20]
# val acc:58.0000 Epoch[17/20]
# Epoch[18/20]
# train loss:1.7208 Epoch[18/20] Batch[0/500]
# val loss:1.1788 Epoch[18/20]
# val acc:60.0000 Epoch[18/20]
# Epoch[19/20]
# train loss:1.7535 Epoch[19/20] Batch[0/500]
# val loss:1.1811 Epoch[19/20]
# val acc:62.0000 Epoch[19/20]
# Epoch[20/20]
# train loss:1.7679 Epoch[20/20] Batch[0/500]
# val loss:1.1501 Epoch[20/20]
# val acc:58.0000 Epoch[20/20]
# Test Accuracy of the model on the test images: 55.97 %
