# %%
import lambdas

# %%
lambdas.show(lambdas.linear(4, 8))
# Out:
# [0.5        0.33333333 0.16666667 0.        ]
# [0.46875    0.32291667 0.17708333 0.03125   ]
# [0.4375 0.3125 0.1875 0.0625]
# [0.40625    0.30208333 0.19791667 0.09375   ]
# [0.375      0.29166667 0.20833333 0.125     ]
# [0.34375 0.28125 0.21875 0.15625]
# [0.3125     0.27083333 0.22916667 0.1875    ]
# [0.28125    0.26041667 0.23958333 0.21875   ]

# %%
lambdas.show(lambdas.invpow(5, 5))
# Out:
# [8.33440514e-01 1.38906752e-01 2.31511254e-02 3.85852090e-03
#  6.43086817e-04]
# [0.80025608 0.16005122 0.03201024 0.00640205 0.00128041]
# [0.75073314 0.18768328 0.04692082 0.01173021 0.00293255]
# [0.66942149 0.2231405  0.07438017 0.02479339 0.00826446]
# [0.51612903 0.25806452 0.12903226 0.06451613 0.03225806]

# %%
lambdas.show(lambdas.sigmoid(6, 3))
# Out:
# [0.29359903 0.25617493 0.19956255 0.13377078 0.07715841 0.03973431]
# [0.32733793 0.3056091  0.22999149 0.10334184 0.02772423 0.0059954 ]
# [0.33250913 0.32446767 0.25617493 0.07715841 0.00886566 0.00082421]
