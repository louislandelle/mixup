# %%
import sys
sys.path.append("/home/landelle/pytorch-cifar/models")
PATH_TO_EFFICIENT_NET = "/home/landelle/EfficientNet-PyTorch"
sys.path.append(PATH_TO_EFFICIENT_NET)

import random
import numpy as np
import pandas as pd
import torch
import torchvision
import datetime

# Local files
import resnet
import main

# %%
SEED = 2019
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.backends.cudnn.deterministic=True
torch.backends.cudnn.benchmark = False

# %%
transform = torchvision.transforms.transforms.Compose([
    torchvision.transforms.transforms.ToTensor()
])

trainset = torchvision.datasets.CIFAR10(root='datasets', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='datasets', train=False, download=True, transform=transform)

classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
trainset, testset
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (Dataset CIFAR10
#      Number of datapoints: 50000
#      Root location: datasets
#      Split: Train
#      StandardTransform
#  Transform: Compose(
#                 ToTensor()
#             ), Dataset CIFAR10
#      Number of datapoints: 10000
#      Root location: datasets
#      Split: Test
#      StandardTransform
#  Transform: Compose(
#                 ToTensor()
#             ))

# %%
STATE_DICTS_PATH = "/home/landelle/state_dicts/"
STATE_DICTS_PREFIX = "state_dict_resnet18"

BATCH_SIZE = 50
N_BATCHES_IN_TRAIN_SET = len(trainset) // BATCH_SIZE
N_BATCHES_IN_TEST_SET = len(testset) // BATCH_SIZE

NUM_WORKERS = 8

# Fixed learning rate
LR = 0.1 #0.005 LR=0.1 is used by kuangliu with his implementation of ResNet18 for epochs [0;150)

# CIFAR10 number of classes
NUM_CLASS = 10

# CIFAR10 image metadata
CHANNEL, IMAGE_SIZE, _ = trainset[0][0].shape
print("images are:", IMAGE_SIZE, CHANNEL)

TRAIN_EPOCHS = 5
# Out:
# images are: 32 3

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# %%
def get_model():
    """ Get model is used to remake the model between lambda attempts """
    return resnet.ResNet18()

def get_print(save_raw=False, f_path="results"):
    """ Makes print function to allow keeping output on disk """
    def print_(*a, **kwa):
        if save_raw:
            with open(f_path, "a") as f:
                t = datetime.datetime.now()
                f.write(str(t) + '    ' + ' '.join([str(x) for x in a]) + '\n')
        print(*a, **kwa)
    return print_

# %%
def train(device, model, optimizer, criterion, lam, n_epochs=None, n_batches=None,
          save_raw=False, save_state_dicts="", save_tensorboard=""):
    """
    save_raw: save raw results (also print to external file) 
    save_state_dicts: No|Override|Separate, saves state_dicts after an epoch
    save_tensorboard: saves tensorboard data
    """
    print_ = get_print(save_raw)
    
    # switch to train mode
    model.train()
    n_epochs = n_epochs if n_epochs else TRAIN_EPOCHS
    for epoch in range(1, n_epochs + 1):
        print_("Epoch[{}/{}]".format(epoch, n_epochs))
        for batch_id, (images, labels) in enumerate(trainloader):
            if n_batches and batch_id > n_batches:
                break            
            labels, images = labels.to(device), images.to(device)
            images, labels_a, labels_b, lam = main.mixup_data(images, labels, lam)
            outputs = model(images)
            loss = main.mixup_criterion(criterion, outputs, labels_a, labels_b, lam)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            if batch_id % 50 == 0:
                print_('Loss :{:.4f} Epoch[{}/{}] Batch[{}/{}] batch_shape:{}'.format(
                    loss.item(), epoch, n_epochs, batch_id, N_BATCHES_IN_TRAIN_SET, images.shape))
        # Each epoch if enabled: save state dicts
        if save_state_dicts=="Separate":
            torch.save(model.state_dict(), STATE_DICTS_DIR + STATE_DICTS_PREFIX + "_epoch_" + str(epoch))
        elif save_state_dicts=="Override":
            torch.save(model.state_dict(), STATE_DICTS_DIR + STATE_DICTS_PREFIX + "_override")

# %%
def test(device, model, save_raw=False):
    print_ = get_print(save_raw)
        
    # switch to evaluate mode
    model.eval()
    with torch.no_grad():
        correct = 0
        total = 0
        for images, labels in testloader:
            images = images.to(device)
            labels = labels.to(device)
            outputs = model(images)
            predicted = torch.argmax(outputs, dim=1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()
        # Output test accuracy
        test_acc = 100 * correct / total
        print_('Test Accuracy of the model on the test images: {} %'.format(test_acc))
        return test_acc

# %%
def collect_results(n_epochs=10, n_batches=None, half=False, no_mixup=False,
                    save_raw=False, save_state_dicts=False, save_tensorboard=False):
    """
    n_batches: None trains on whole dataset otherwise it trains on n_batches of BATCH_SIZE per epoch    
    
    """
    USE_CUDA = True
    print_ = get_print(save_raw)

    test_accs = {}
    for lambda_ in [x*.1 for x in range(11)]:
        if half and lambda_>.5:
            break
        if no_mixup and lambda_>0:
            break
        print_("Trying lambda=", lambda_)        

        device = torch.device('cuda' if USE_CUDA else 'cpu')
        #model = models.My_Model(NUM_CLASS).to(device)
        #model = EfficientNet.from_pretrained('efficientnet-b0').to(device)
        model = get_model().to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=LR)
        criterion = torch.nn.CrossEntropyLoss()

        train(device, model, optimizer, criterion, lambda_, n_epochs, n_batches, save_raw, save_state_dicts, save_tensorboard)
        test_accs[lambda_] = test(device, model, save_raw)

        del device, model, optimizer, criterion
    test_accs_dict = {str(k)[:3]:[v] for k, v in test_accs.items()}
    test_accs_df = pd.DataFrame.from_dict(test_accs_dict).transpose()
    test_accs_df.reset_index(inplace=True)
    test_accs_df.rename(columns={0:'Test accuracy', 'index':'Lambda'}, inplace=True)
    print_(test_accs_df)
    return test_accs_df

# %%
SAVE_RAW = True
if SAVE_RAW:
    with open("results", "w") as f: pass
test_accs2 = collect_results(n_epochs=30, n_batches=None, save_raw=SAVE_RAW)
# Out:
# Trying lambda= 0.0
# Epoch[1/30]
# Loss :2.3883 Epoch[1/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.3023 Epoch[1/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.2938 Epoch[1/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.2985 Epoch[1/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.2340 Epoch[1/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.2772 Epoch[1/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.3511 Epoch[1/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.1720 Epoch[1/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.0015 Epoch[1/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.2949 Epoch[1/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.1833 Epoch[1/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.1352 Epoch[1/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8807 Epoch[1/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.9471 Epoch[1/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8449 Epoch[1/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7983 Epoch[1/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.9842 Epoch[1/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.0868 Epoch[1/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8870 Epoch[1/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6921 Epoch[1/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[2/30]
# Loss :1.5781 Epoch[2/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.9714 Epoch[2/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7313 Epoch[2/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5663 Epoch[2/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8986 Epoch[2/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6911 Epoch[2/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8793 Epoch[2/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7186 Epoch[2/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6875 Epoch[2/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4386 Epoch[2/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5764 Epoch[2/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7718 Epoch[2/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4990 Epoch[2/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5809 Epoch[2/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7743 Epoch[2/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4892 Epoch[2/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8790 Epoch[2/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6347 Epoch[2/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7118 Epoch[2/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6570 Epoch[2/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[3/30]
# Loss :1.5397 Epoch[3/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3329 Epoch[3/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2761 Epoch[3/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5424 Epoch[3/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3366 Epoch[3/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6178 Epoch[3/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7640 Epoch[3/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3465 Epoch[3/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4520 Epoch[3/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4202 Epoch[3/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2490 Epoch[3/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2286 Epoch[3/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3895 Epoch[3/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4371 Epoch[3/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4049 Epoch[3/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2671 Epoch[3/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2760 Epoch[3/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5058 Epoch[3/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4196 Epoch[3/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3576 Epoch[3/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[4/30]
# Loss :1.1582 Epoch[4/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4395 Epoch[4/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5259 Epoch[4/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2297 Epoch[4/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1489 Epoch[4/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3586 Epoch[4/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1860 Epoch[4/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1702 Epoch[4/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0080 Epoch[4/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1450 Epoch[4/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1475 Epoch[4/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1961 Epoch[4/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9627 Epoch[4/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4081 Epoch[4/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3493 Epoch[4/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2820 Epoch[4/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4926 Epoch[4/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0067 Epoch[4/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2584 Epoch[4/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0375 Epoch[4/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[5/30]
# Loss :1.3950 Epoch[5/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9676 Epoch[5/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3460 Epoch[5/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3340 Epoch[5/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3093 Epoch[5/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9204 Epoch[5/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9695 Epoch[5/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9894 Epoch[5/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3398 Epoch[5/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3141 Epoch[5/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9082 Epoch[5/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9695 Epoch[5/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1255 Epoch[5/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7586 Epoch[5/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0166 Epoch[5/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0571 Epoch[5/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0563 Epoch[5/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7636 Epoch[5/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7208 Epoch[5/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8666 Epoch[5/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[6/30]
# Loss :1.1438 Epoch[6/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9678 Epoch[6/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0032 Epoch[6/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8861 Epoch[6/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0617 Epoch[6/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0341 Epoch[6/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5760 Epoch[6/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6785 Epoch[6/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2266 Epoch[6/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0630 Epoch[6/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9260 Epoch[6/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0841 Epoch[6/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0527 Epoch[6/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9533 Epoch[6/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7701 Epoch[6/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8702 Epoch[6/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0661 Epoch[6/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0669 Epoch[6/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0808 Epoch[6/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8396 Epoch[6/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[7/30]
# Loss :1.0180 Epoch[7/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6431 Epoch[7/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0346 Epoch[7/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9985 Epoch[7/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9406 Epoch[7/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1239 Epoch[7/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8559 Epoch[7/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7243 Epoch[7/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7980 Epoch[7/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7454 Epoch[7/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9605 Epoch[7/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7327 Epoch[7/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4968 Epoch[7/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7272 Epoch[7/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7425 Epoch[7/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1043 Epoch[7/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0235 Epoch[7/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3474 Epoch[7/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9130 Epoch[7/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8069 Epoch[7/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[8/30]
# Loss :0.6550 Epoch[8/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8440 Epoch[8/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4476 Epoch[8/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6253 Epoch[8/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8618 Epoch[8/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5985 Epoch[8/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7700 Epoch[8/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5915 Epoch[8/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7748 Epoch[8/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7155 Epoch[8/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7614 Epoch[8/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0407 Epoch[8/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8585 Epoch[8/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5369 Epoch[8/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5064 Epoch[8/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6020 Epoch[8/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8292 Epoch[8/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6259 Epoch[8/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7768 Epoch[8/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0267 Epoch[8/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[9/30]
# Loss :0.8096 Epoch[9/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4412 Epoch[9/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6391 Epoch[9/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6107 Epoch[9/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6803 Epoch[9/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6009 Epoch[9/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8290 Epoch[9/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4352 Epoch[9/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7794 Epoch[9/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4156 Epoch[9/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7072 Epoch[9/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5428 Epoch[9/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7583 Epoch[9/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5557 Epoch[9/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9267 Epoch[9/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7380 Epoch[9/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7127 Epoch[9/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8208 Epoch[9/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3547 Epoch[9/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5136 Epoch[9/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[10/30]
# Loss :0.4839 Epoch[10/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5007 Epoch[10/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7807 Epoch[10/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4622 Epoch[10/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5884 Epoch[10/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5083 Epoch[10/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4777 Epoch[10/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5645 Epoch[10/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7417 Epoch[10/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4915 Epoch[10/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5528 Epoch[10/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4383 Epoch[10/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3050 Epoch[10/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8898 Epoch[10/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4564 Epoch[10/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6478 Epoch[10/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2905 Epoch[10/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1048 Epoch[10/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9005 Epoch[10/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5460 Epoch[10/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[11/30]
# Loss :0.6791 Epoch[11/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4520 Epoch[11/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3621 Epoch[11/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5849 Epoch[11/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3761 Epoch[11/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4000 Epoch[11/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5731 Epoch[11/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4140 Epoch[11/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5191 Epoch[11/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7145 Epoch[11/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6892 Epoch[11/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4690 Epoch[11/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8408 Epoch[11/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6208 Epoch[11/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4896 Epoch[11/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5495 Epoch[11/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5571 Epoch[11/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5043 Epoch[11/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8082 Epoch[11/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5810 Epoch[11/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[12/30]
# Loss :0.2309 Epoch[12/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1733 Epoch[12/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2921 Epoch[12/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4297 Epoch[12/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4433 Epoch[12/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5122 Epoch[12/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5556 Epoch[12/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4667 Epoch[12/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5987 Epoch[12/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3475 Epoch[12/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4085 Epoch[12/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1796 Epoch[12/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5688 Epoch[12/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3362 Epoch[12/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3926 Epoch[12/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4758 Epoch[12/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3212 Epoch[12/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5395 Epoch[12/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4158 Epoch[12/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6677 Epoch[12/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[13/30]
# Loss :0.6232 Epoch[13/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5413 Epoch[13/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2334 Epoch[13/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4376 Epoch[13/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1490 Epoch[13/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2810 Epoch[13/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2308 Epoch[13/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5814 Epoch[13/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5366 Epoch[13/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5750 Epoch[13/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3855 Epoch[13/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3451 Epoch[13/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2594 Epoch[13/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2399 Epoch[13/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2419 Epoch[13/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5335 Epoch[13/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2733 Epoch[13/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3227 Epoch[13/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4914 Epoch[13/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4699 Epoch[13/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[14/30]
# Loss :0.2637 Epoch[14/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2716 Epoch[14/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2291 Epoch[14/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2977 Epoch[14/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5499 Epoch[14/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1326 Epoch[14/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2444 Epoch[14/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3987 Epoch[14/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4352 Epoch[14/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3309 Epoch[14/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1875 Epoch[14/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3967 Epoch[14/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2780 Epoch[14/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1991 Epoch[14/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2427 Epoch[14/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3174 Epoch[14/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2346 Epoch[14/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1818 Epoch[14/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4644 Epoch[14/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4397 Epoch[14/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[15/30]
# Loss :0.1318 Epoch[15/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1346 Epoch[15/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3566 Epoch[15/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2397 Epoch[15/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5671 Epoch[15/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1945 Epoch[15/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2940 Epoch[15/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2697 Epoch[15/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3863 Epoch[15/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2590 Epoch[15/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3134 Epoch[15/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4879 Epoch[15/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3471 Epoch[15/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2538 Epoch[15/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1067 Epoch[15/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3303 Epoch[15/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.5036 Epoch[15/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1811 Epoch[15/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2469 Epoch[15/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1857 Epoch[15/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[16/30]
# Loss :0.1267 Epoch[16/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1540 Epoch[16/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0397 Epoch[16/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2439 Epoch[16/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2335 Epoch[16/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2377 Epoch[16/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2599 Epoch[16/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3510 Epoch[16/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1473 Epoch[16/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1682 Epoch[16/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4375 Epoch[16/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1875 Epoch[16/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3567 Epoch[16/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2588 Epoch[16/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1582 Epoch[16/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1710 Epoch[16/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3415 Epoch[16/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2823 Epoch[16/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2127 Epoch[16/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.7070 Epoch[16/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[17/30]
# Loss :0.1729 Epoch[17/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1376 Epoch[17/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1210 Epoch[17/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0263 Epoch[17/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2439 Epoch[17/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1364 Epoch[17/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1138 Epoch[17/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1631 Epoch[17/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2348 Epoch[17/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4484 Epoch[17/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0753 Epoch[17/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2663 Epoch[17/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1608 Epoch[17/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2566 Epoch[17/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1847 Epoch[17/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0940 Epoch[17/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2291 Epoch[17/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1399 Epoch[17/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2790 Epoch[17/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2280 Epoch[17/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[18/30]
# Loss :0.1779 Epoch[18/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1875 Epoch[18/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1308 Epoch[18/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1412 Epoch[18/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1747 Epoch[18/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2636 Epoch[18/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3169 Epoch[18/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1509 Epoch[18/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1050 Epoch[18/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2750 Epoch[18/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2109 Epoch[18/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1595 Epoch[18/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0685 Epoch[18/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1226 Epoch[18/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3084 Epoch[18/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1014 Epoch[18/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1961 Epoch[18/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1859 Epoch[18/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0459 Epoch[18/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2971 Epoch[18/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[19/30]
# Loss :0.4383 Epoch[19/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1967 Epoch[19/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2363 Epoch[19/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1025 Epoch[19/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2449 Epoch[19/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2612 Epoch[19/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0413 Epoch[19/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2336 Epoch[19/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1310 Epoch[19/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1429 Epoch[19/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1512 Epoch[19/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2827 Epoch[19/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4063 Epoch[19/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2656 Epoch[19/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3145 Epoch[19/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3289 Epoch[19/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3281 Epoch[19/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1267 Epoch[19/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2847 Epoch[19/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3531 Epoch[19/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[20/30]
# Loss :0.2194 Epoch[20/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2734 Epoch[20/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0923 Epoch[20/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0420 Epoch[20/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2334 Epoch[20/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2164 Epoch[20/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0284 Epoch[20/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0545 Epoch[20/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4322 Epoch[20/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1477 Epoch[20/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2695 Epoch[20/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1814 Epoch[20/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0767 Epoch[20/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0663 Epoch[20/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2387 Epoch[20/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2259 Epoch[20/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1367 Epoch[20/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1737 Epoch[20/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2733 Epoch[20/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2603 Epoch[20/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[21/30]
# Loss :0.1894 Epoch[21/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0521 Epoch[21/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1778 Epoch[21/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0304 Epoch[21/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0567 Epoch[21/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0496 Epoch[21/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1960 Epoch[21/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2200 Epoch[21/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1857 Epoch[21/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0420 Epoch[21/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2572 Epoch[21/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0638 Epoch[21/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0773 Epoch[21/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2982 Epoch[21/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1140 Epoch[21/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1393 Epoch[21/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2592 Epoch[21/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0939 Epoch[21/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3156 Epoch[21/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1630 Epoch[21/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[22/30]
# Loss :0.0900 Epoch[22/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0825 Epoch[22/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0677 Epoch[22/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1375 Epoch[22/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3489 Epoch[22/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2155 Epoch[22/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0091 Epoch[22/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2369 Epoch[22/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1862 Epoch[22/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1505 Epoch[22/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1486 Epoch[22/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0611 Epoch[22/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0527 Epoch[22/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1411 Epoch[22/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1452 Epoch[22/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1286 Epoch[22/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1465 Epoch[22/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2024 Epoch[22/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1059 Epoch[22/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2703 Epoch[22/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[23/30]
# Loss :0.0799 Epoch[23/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0565 Epoch[23/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1065 Epoch[23/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0506 Epoch[23/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0403 Epoch[23/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1477 Epoch[23/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0511 Epoch[23/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1714 Epoch[23/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1698 Epoch[23/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2644 Epoch[23/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1954 Epoch[23/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1731 Epoch[23/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0740 Epoch[23/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3942 Epoch[23/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3657 Epoch[23/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0701 Epoch[23/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3778 Epoch[23/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2883 Epoch[23/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0442 Epoch[23/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0590 Epoch[23/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[24/30]
# Loss :0.1022 Epoch[24/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0815 Epoch[24/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1566 Epoch[24/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1957 Epoch[24/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1444 Epoch[24/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1717 Epoch[24/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1100 Epoch[24/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1277 Epoch[24/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1439 Epoch[24/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1176 Epoch[24/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1069 Epoch[24/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0733 Epoch[24/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1154 Epoch[24/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.6761 Epoch[24/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1940 Epoch[24/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1438 Epoch[24/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0119 Epoch[24/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0697 Epoch[24/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1519 Epoch[24/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2903 Epoch[24/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[25/30]
# Loss :0.0977 Epoch[25/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0725 Epoch[25/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0860 Epoch[25/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2116 Epoch[25/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0136 Epoch[25/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1651 Epoch[25/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0862 Epoch[25/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0482 Epoch[25/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0412 Epoch[25/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0970 Epoch[25/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1835 Epoch[25/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3185 Epoch[25/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3405 Epoch[25/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0979 Epoch[25/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0996 Epoch[25/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1535 Epoch[25/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0403 Epoch[25/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0815 Epoch[25/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1486 Epoch[25/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1143 Epoch[25/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[26/30]
# Loss :0.0314 Epoch[26/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2124 Epoch[26/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1422 Epoch[26/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0351 Epoch[26/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1409 Epoch[26/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0696 Epoch[26/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1110 Epoch[26/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0666 Epoch[26/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0107 Epoch[26/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2247 Epoch[26/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0492 Epoch[26/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3277 Epoch[26/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1242 Epoch[26/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2812 Epoch[26/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2364 Epoch[26/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0576 Epoch[26/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1060 Epoch[26/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0577 Epoch[26/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1014 Epoch[26/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1162 Epoch[26/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[27/30]
# Loss :0.1644 Epoch[27/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0809 Epoch[27/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0712 Epoch[27/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0179 Epoch[27/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1244 Epoch[27/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0511 Epoch[27/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0494 Epoch[27/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0608 Epoch[27/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1636 Epoch[27/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0981 Epoch[27/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0206 Epoch[27/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1462 Epoch[27/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0589 Epoch[27/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0246 Epoch[27/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1162 Epoch[27/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0268 Epoch[27/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1247 Epoch[27/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2642 Epoch[27/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1320 Epoch[27/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0280 Epoch[27/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[28/30]
# Loss :0.0454 Epoch[28/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1154 Epoch[28/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0314 Epoch[28/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1046 Epoch[28/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0396 Epoch[28/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0083 Epoch[28/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1361 Epoch[28/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0430 Epoch[28/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0688 Epoch[28/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2673 Epoch[28/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0772 Epoch[28/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0382 Epoch[28/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2077 Epoch[28/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0582 Epoch[28/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0086 Epoch[28/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2941 Epoch[28/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0222 Epoch[28/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0915 Epoch[28/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0734 Epoch[28/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1972 Epoch[28/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[29/30]
# Loss :0.0048 Epoch[29/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0450 Epoch[29/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0665 Epoch[29/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1011 Epoch[29/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0282 Epoch[29/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1416 Epoch[29/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0684 Epoch[29/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1272 Epoch[29/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0590 Epoch[29/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1950 Epoch[29/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1126 Epoch[29/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2231 Epoch[29/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0533 Epoch[29/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0271 Epoch[29/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1212 Epoch[29/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1344 Epoch[29/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1436 Epoch[29/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2643 Epoch[29/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1516 Epoch[29/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1545 Epoch[29/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[30/30]
# Loss :0.0054 Epoch[30/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1647 Epoch[30/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0506 Epoch[30/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# ...
# Loss :0.1658 Epoch[21/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0657 Epoch[21/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0734 Epoch[21/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2543 Epoch[21/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4232 Epoch[21/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0409 Epoch[21/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3236 Epoch[21/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0400 Epoch[21/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0505 Epoch[21/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[22/30]
# Loss :0.1587 Epoch[22/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0511 Epoch[22/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0840 Epoch[22/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1625 Epoch[22/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1856 Epoch[22/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0420 Epoch[22/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0862 Epoch[22/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0767 Epoch[22/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0851 Epoch[22/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1189 Epoch[22/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2245 Epoch[22/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2386 Epoch[22/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0742 Epoch[22/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0595 Epoch[22/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0821 Epoch[22/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.3782 Epoch[22/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4546 Epoch[22/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0655 Epoch[22/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0090 Epoch[22/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0803 Epoch[22/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[23/30]
# Loss :0.0419 Epoch[23/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1343 Epoch[23/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0405 Epoch[23/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0660 Epoch[23/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2254 Epoch[23/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0308 Epoch[23/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0289 Epoch[23/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0693 Epoch[23/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1289 Epoch[23/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0816 Epoch[23/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0477 Epoch[23/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0430 Epoch[23/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0323 Epoch[23/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2567 Epoch[23/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0821 Epoch[23/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0918 Epoch[23/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0284 Epoch[23/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.4431 Epoch[23/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1657 Epoch[23/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1398 Epoch[23/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[24/30]
# Loss :0.0243 Epoch[24/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0420 Epoch[24/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0155 Epoch[24/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0677 Epoch[24/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0944 Epoch[24/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0117 Epoch[24/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0085 Epoch[24/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0467 Epoch[24/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0999 Epoch[24/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0425 Epoch[24/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0270 Epoch[24/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1610 Epoch[24/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1024 Epoch[24/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1373 Epoch[24/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0750 Epoch[24/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0237 Epoch[24/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0708 Epoch[24/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0189 Epoch[24/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0812 Epoch[24/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0839 Epoch[24/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[25/30]
# Loss :0.0389 Epoch[25/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1620 Epoch[25/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0119 Epoch[25/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0066 Epoch[25/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0880 Epoch[25/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2253 Epoch[25/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0114 Epoch[25/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0696 Epoch[25/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0394 Epoch[25/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0615 Epoch[25/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2114 Epoch[25/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0528 Epoch[25/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1105 Epoch[25/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0651 Epoch[25/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0463 Epoch[25/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1878 Epoch[25/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0921 Epoch[25/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0375 Epoch[25/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1216 Epoch[25/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0427 Epoch[25/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[26/30]
# Loss :0.1052 Epoch[26/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0909 Epoch[26/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0434 Epoch[26/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0260 Epoch[26/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0307 Epoch[26/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1187 Epoch[26/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0108 Epoch[26/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0511 Epoch[26/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0686 Epoch[26/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0447 Epoch[26/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0493 Epoch[26/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1196 Epoch[26/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1361 Epoch[26/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2775 Epoch[26/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1050 Epoch[26/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1006 Epoch[26/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0220 Epoch[26/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1557 Epoch[26/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0276 Epoch[26/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0986 Epoch[26/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[27/30]
# Loss :0.0090 Epoch[27/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0230 Epoch[27/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1348 Epoch[27/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0251 Epoch[27/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0650 Epoch[27/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0970 Epoch[27/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0731 Epoch[27/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0305 Epoch[27/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1027 Epoch[27/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1336 Epoch[27/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1970 Epoch[27/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0044 Epoch[27/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1319 Epoch[27/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1587 Epoch[27/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1445 Epoch[27/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2784 Epoch[27/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0310 Epoch[27/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1916 Epoch[27/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2069 Epoch[27/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2621 Epoch[27/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[28/30]
# Loss :0.0577 Epoch[28/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1104 Epoch[28/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0489 Epoch[28/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0289 Epoch[28/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0133 Epoch[28/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0970 Epoch[28/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1307 Epoch[28/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0111 Epoch[28/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1738 Epoch[28/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0596 Epoch[28/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0312 Epoch[28/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0316 Epoch[28/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0712 Epoch[28/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0148 Epoch[28/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1757 Epoch[28/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0359 Epoch[28/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0736 Epoch[28/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2308 Epoch[28/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0452 Epoch[28/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1246 Epoch[28/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[29/30]
# Loss :0.0223 Epoch[29/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0685 Epoch[29/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0311 Epoch[29/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0452 Epoch[29/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0823 Epoch[29/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0257 Epoch[29/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0168 Epoch[29/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1460 Epoch[29/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0399 Epoch[29/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0473 Epoch[29/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1789 Epoch[29/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0045 Epoch[29/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0690 Epoch[29/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2586 Epoch[29/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2651 Epoch[29/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.2123 Epoch[29/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0540 Epoch[29/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0430 Epoch[29/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0333 Epoch[29/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1144 Epoch[29/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[30/30]
# Loss :0.0823 Epoch[30/30] Batch[0/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0389 Epoch[30/30] Batch[50/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0528 Epoch[30/30] Batch[100/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0437 Epoch[30/30] Batch[150/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0060 Epoch[30/30] Batch[200/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0359 Epoch[30/30] Batch[250/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0179 Epoch[30/30] Batch[300/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0292 Epoch[30/30] Batch[350/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0102 Epoch[30/30] Batch[400/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1930 Epoch[30/30] Batch[450/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1497 Epoch[30/30] Batch[500/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0949 Epoch[30/30] Batch[550/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0596 Epoch[30/30] Batch[600/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0813 Epoch[30/30] Batch[650/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1511 Epoch[30/30] Batch[700/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.1313 Epoch[30/30] Batch[750/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0616 Epoch[30/30] Batch[800/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0089 Epoch[30/30] Batch[850/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0700 Epoch[30/30] Batch[900/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.0506 Epoch[30/30] Batch[950/1000] batch_shape:torch.Size([50, 3, 32, 32])
# Test Accuracy of the model on the test images: 79.22 %
#    Lambda  Test accuracy
# 0     0.0          77.63
# 1     0.1          80.81
# 2     0.2          81.02
# 3     0.3          76.91
# 4     0.4          81.44
# 5     0.5          51.52
# 6     0.6          55.78
# 7     0.7          82.32
# 8     0.8          82.17
# 9     0.9          81.18
# 10    1.0          79.22

# %%
test_accs2
