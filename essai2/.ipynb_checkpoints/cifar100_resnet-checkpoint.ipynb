# %%
import sys
sys.path.append("/home/landelle/pytorch-cifar/models")
import util
import resnet
import torch
import torchvision

# %%
transform = torchvision.transforms.transforms.Compose([
    torchvision.transforms.transforms.ToTensor()
])

trainset = torchvision.datasets.CIFAR100(root='datasets', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR100(root='datasets', train=False, download=True, transform=transform)

trainset, testset
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (Dataset CIFAR100
#      Number of datapoints: 50000
#      Root location: datasets
#      Split: Train
#      StandardTransform
#  Transform: Compose(
#                 ToTensor()
#             ), Dataset CIFAR100
#      Number of datapoints: 10000
#      Root location: datasets
#      Split: Test
#      StandardTransform
#  Transform: Compose(
#                 ToTensor()
#             ))

# %%
BATCH_SIZE = 100
N_BATCHES_IN_TRAIN_SET = len(trainset) // BATCH_SIZE
N_BATCHES_IN_TEST_SET = len(testset) // BATCH_SIZE

NUM_WORKERS = 8

# Fixed learning rate
LR = 0.1 #0.005 LR=0.1 is used by kuangliu with his implementation of ResNet18 for epochs [0;150)

# CIFAR100 number of classes
NUM_CLASS = 100

# CIFAR100 image metadata
CHANNEL, IMAGE_SIZE, _ = trainset[0][0].shape
print("images are:", IMAGE_SIZE, CHANNEL)

TRAIN_EPOCHS = 5
print(N_BATCHES_IN_TRAIN_SET)
# Out:
# images are: 32 3
# 500

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# %%
def get_model():
    """ Get model is used to remake the model between lambda attempts """
    return resnet.ResNet18_100()


CUSTOM_LAMBDAS = [x*.25 for x in range(5)]
print(CUSTOM_LAMBDAS)

SAVE_RAW = True
if SAVE_RAW:
    with open("results", "w") as f: pass
test_accs2 = util.collect_results(trainloader, testloader, model_getter=get_model,
                                  n_epochs=50, n_batches=10, save_raw=SAVE_RAW, custom_lambdas=CUSTOM_LAMBDAS)
# Out:
# [0.0, 0.25, 0.5, 0.75, 1.0]
# Trying lambda= 0.0
# Epoch[1/1]
# Loss :4.7053 Epoch[1/1] Batch[0/500] batch_shape:torch.Size([100, 3, 32, 32])
# Test Accuracy of the model on the test images: 1.02 %
# Trying lambda= 0.25
# Epoch[1/1]
# Loss :4.6714 Epoch[1/1] Batch[0/500] batch_shape:torch.Size([100, 3, 32, 32])
# Test Accuracy of the model on the test images: 1.15 %
# Trying lambda= 0.5
# Epoch[1/1]
# Loss :4.6749 Epoch[1/1] Batch[0/500] batch_shape:torch.Size([100, 3, 32, 32])
# Test Accuracy of the model on the test images: 1.0 %
# Trying lambda= 0.75
# Epoch[1/1]
# Loss :4.8144 Epoch[1/1] Batch[0/500] batch_shape:torch.Size([100, 3, 32, 32])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-06e92800065d> in <module>
#      11     with open("results", "w") as f: pass
#      12 test_accs2 = util.collect_results(trainloader, testloader, model_getter=get_model,
# ---> 13                                   n_epochs=1, n_batches=10, save_raw=SAVE_RAW, custom_lambdas=CUSTOM_LAMBDAS)
#
# ~/mixup/essai2/util.py in collect_results(trainloader, testloader, model_getter, n_epochs, n_batches, half, no_mixup, save_raw, save_state_dicts, save_tensorboard, custom_lambdas, LR, TRAIN_EPOCHS, N_BATCHES_IN_TRAIN_SET)
#     122               n_epochs=n_epochs, n_batches=n_batches,
#     123               save_raw=save_raw, save_state_dicts=save_state_dicts, save_tensorboard=save_tensorboard,
# --> 124              LR=LR, TRAIN_EPOCHS=TRAIN_EPOCHS, N_BATCHES_IN_TRAIN_SET=N_BATCHES_IN_TRAIN_SET)
#     125         test_accs[lambda_] = test(device, model, testloader, save_raw=save_raw)
#     126
#
# ~/mixup/essai2/util.py in train(device, model, optimizer, criterion, lam, trainloader, n_epochs, n_batches, save_raw, save_state_dicts, save_tensorboard, LR, TRAIN_EPOCHS, N_BATCHES_IN_TRAIN_SET)
#      54             if n_batches and batch_id > n_batches:
#      55                 break
# ---> 56             labels, images = labels.to(device), images.to(device)
#      57             images, labels_a, labels_b, lam = main.mixup_data(images, labels, lam)
#      58             outputs = model(images)
#
# KeyboardInterrupt:
