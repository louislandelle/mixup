# %%
import sys
sys.path.append("/home/landelle/pytorch-cifar/models")
#import util
import resnet
import numpy as np
import torch
import torchvision

import nmixup

# %%
transform = torchvision.transforms.transforms.Compose([
    torchvision.transforms.transforms.ToTensor()
])

trainset = torchvision.datasets.CIFAR10(root='/data/landelle/datasets', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='/data/landelle/datasets', train=False, download=True, transform=transform)

trainset, testset
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# (Dataset CIFAR10
#      Number of datapoints: 50000
#      Root location: /data/landelle/datasets
#      Split: Train
#      StandardTransform
#  Transform: Compose(
#                 ToTensor()
#             ), Dataset CIFAR10
#      Number of datapoints: 10000
#      Root location: /data/landelle/datasets
#      Split: Test
#      StandardTransform
#  Transform: Compose(
#                 ToTensor()
#             ))

# %%
BATCH_SIZE = 100
N_BATCHES_IN_TRAIN_SET = len(trainset) // BATCH_SIZE
N_BATCHES_IN_TEST_SET = len(testset) // BATCH_SIZE

NUM_WORKERS = 8

# Fixed learning rate
LR = 0.05 #0.005 LR=0.1 is used by kuangliu with his implementation of ResNet18 for epochs [0;150)

# CIFAR10 number of classes
NUM_CLASS = 10

# CIFAR10 image metadata
CHANNEL, IMAGE_SIZE, _ = trainset[0][0].shape
print("images are:", IMAGE_SIZE, CHANNEL)
# Out:
# images are: 32 3

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# %%
LAMBDAS = np.zeros((6, 3))

LAMBDAS[0] = np.array((1, 0, 0))
for i in range(1, 6):
    decr = 6-i#2
    lam_try = np.array((1, 1/decr, 1/(decr*decr)))
    lam_try_normalized = lam_try / lam_try.sum()
    LAMBDAS[i] = lam_try_normalized

print(LAMBDAS)
# Out:
# [[1.         0.         0.        ]
#  [0.80645161 0.16129032 0.03225806]
#  [0.76190476 0.19047619 0.04761905]
#  [0.69230769 0.23076923 0.07692308]
#  [0.57142857 0.28571429 0.14285714]
#  [0.33333333 0.33333333 0.33333333]]

# %%
RESULTS_FNAME = "results_1"
SAVE_RAW = True
if SAVE_RAW:
    with open("results/"+RESULTS_FNAME, "w") as f: pass
test_accs2 = nmixup.collect_results_nmix(trainloader, testloader, LAMBDAS, model_getter=nmixup.resnet18,
                                  n_epochs=100, n_batches=None, results_fname=RESULTS_FNAME,
                                  save_raw=SAVE_RAW, use_cuda=True, N_BATCHES_IN_TRAIN_SET=N_BATCHES_IN_TRAIN_SET)
# Out:
# Trying lambda= [1. 0. 0.]
# Performing n-mixup with N-mix: 3
# Epoch[1/100]
# Loss :2.5505 Epoch[1/100] Batch[0/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.0999 Epoch[1/100] Batch[50/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.2430 Epoch[1/100] Batch[100/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :2.0040 Epoch[1/100] Batch[150/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8609 Epoch[1/100] Batch[200/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7259 Epoch[1/100] Batch[250/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5344 Epoch[1/100] Batch[300/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.8200 Epoch[1/100] Batch[350/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.7337 Epoch[1/100] Batch[400/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5432 Epoch[1/100] Batch[450/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5687 Epoch[1/100] Batch[500/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3584 Epoch[1/100] Batch[550/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6968 Epoch[1/100] Batch[600/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6377 Epoch[1/100] Batch[650/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4724 Epoch[1/100] Batch[700/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4948 Epoch[1/100] Batch[750/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4215 Epoch[1/100] Batch[800/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.6389 Epoch[1/100] Batch[850/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.5466 Epoch[1/100] Batch[900/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4005 Epoch[1/100] Batch[950/500] batch_shape:torch.Size([50, 3, 32, 32])
# Epoch[2/100]
# Loss :1.2380 Epoch[2/100] Batch[0/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.4400 Epoch[2/100] Batch[50/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3236 Epoch[2/100] Batch[100/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1974 Epoch[2/100] Batch[150/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.3795 Epoch[2/100] Batch[200/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.2045 Epoch[2/100] Batch[250/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1974 Epoch[2/100] Batch[300/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1154 Epoch[2/100] Batch[350/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1242 Epoch[2/100] Batch[400/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1436 Epoch[2/100] Batch[450/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8474 Epoch[2/100] Batch[500/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0535 Epoch[2/100] Batch[550/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9471 Epoch[2/100] Batch[600/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0219 Epoch[2/100] Batch[650/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9165 Epoch[2/100] Batch[700/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9416 Epoch[2/100] Batch[750/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.9679 Epoch[2/100] Batch[800/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.0404 Epoch[2/100] Batch[850/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :1.1585 Epoch[2/100] Batch[900/500] batch_shape:torch.Size([50, 3, 32, 32])
# Loss :0.8705 Epoch[2/100] Batch[950/500] batch_shape:torch.Size([50, 3, 32, 32])
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-bc2743784d8b> in <module>
#       4 test_accs2 = nmixup.collect_results_nmix(trainloader, testloader, LAMBDAS, model_getter=nmixup.resnet18,
#       5                                   n_epochs=100, n_batches=None, results_fname="results_1",
# ----> 6                                   save_raw=SAVE_RAW, use_cuda=True)
#
# ~/mixup/clean/nmixup.py in collect_results_nmix(trainloader, testloader, lambdas, model_getter, n_epochs, n_batches, half, no_mixup, save_raw, save_state_dicts, save_tensorboard, results_fname, LR, TRAIN_EPOCHS, N_BATCHES_IN_TRAIN_SET, use_cuda)
#     156               save_raw=save_raw, save_state_dicts=save_state_dicts, save_tensorboard=save_tensorboard,
#     157               results_fname=results_fname,
# --> 158              LR=LR, TRAIN_EPOCHS=TRAIN_EPOCHS, N_BATCHES_IN_TRAIN_SET=N_BATCHES_IN_TRAIN_SET)
#     159         test_accs[str(lambda_)] = test(device, model, testloader, results_fname=results_fname, save_raw=save_raw)
#     160
#
# ~/mixup/clean/nmixup.py in train(device, model, optimizer, criterion, lam_vec, trainloader, n_epochs, n_batches, save_raw, save_state_dicts, save_tensorboard, results_fname, LR, TRAIN_EPOCHS, N_BATCHES_IN_TRAIN_SET)
#      89             images, ys, perms = mixup_data_nmix(NMIX, images, labels, lam_vec)
#      90             #outputs = model(images.float())
# ---> 91             outputs = model(images)
#      92             loss = mixup_criterion_nmix(criterion, outputs, ys, lam_vec)
#      93
#
# /data/landelle/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/pytorch-cifar/models/resnet.py in forward(self, x)
#      90         out = self.layer1(out)
#      91         out = self.layer2(out)
# ---> 92         out = self.layer3(out)
#      93         out = self.layer4(out)
#      94         out = F.avg_pool2d(out, 4)
#
# /data/landelle/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /data/landelle/anaconda3/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /data/landelle/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/pytorch-cifar/models/resnet.py in forward(self, x)
#      31     def forward(self, x):
#      32         out = F.relu(self.bn1(self.conv1(x)))
# ---> 33         out = self.bn2(self.conv2(out))
#      34         out += self.shortcut(x)
#      35         out = F.relu(out)
#
# /data/landelle/anaconda3/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /data/landelle/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     341
#     342     def forward(self, input):
# --> 343         return self.conv2d_forward(input, self.weight)
#     344
#     345 class Conv3d(_ConvNd):
#
# /data/landelle/anaconda3/lib/python3.7/site-packages/torch/nn/modules/conv.py in conv2d_forward(self, input, weight)
#     338                             _pair(0), self.dilation, self.groups)
#     339         return F.conv2d(input, weight, self.bias, self.stride,
# --> 340                         self.padding, self.dilation, self.groups)
#     341
#     342     def forward(self, input):
#
# KeyboardInterrupt:
