# %% [markdown]
# ## N=2

# %%
import numpy as np
import torch
import torchvision
import matplotlib.pyplot as plt

import utils
import exp_models

# %%
# Reproducibility
SEED = 2019

np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.enabled = False 
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
transform = torchvision.transforms.transforms.Compose([
    torchvision.transforms.transforms.ToTensor()
])
trainset = torchvision.datasets.FashionMNIST(root='/data/landelle/datasets', train=True, download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root='/data/landelle/datasets', train=False, download=True, transform=transform)
#trainset, testset

# %%
BATCH_SIZE = 100
N_BATCHES_IN_TRAIN_SET = len(trainset) // BATCH_SIZE
N_BATCHES_IN_TEST_SET = len(testset) // BATCH_SIZE
NUM_WORKERS = 8

trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# %%
fig, axes = plt.subplots(1, 8, figsize=(15, 2))
for i in range(8):
    utils.show_np_arr(next(iter(trainloader))[0][i][0, :, :], ax=axes[i])
    pass

# %%
USE_CUDA = True
RESULTS_FNAME = "delete"
N_EPOCHS = 5
N_BATCHES = 5
LR = 0.001
LAMBDAS = [np.array([lam, 1-lam]) for lam in np.linspace(1., .5, 5)]
print(LAMBDAS)

print_ = utils.get_print(True, fname=RESULTS_FNAME)
model_getter = exp_models.CNN

def perform_experiment():
    test_accs = {}
    train_losses = {str(k):[] for k in LAMBDAS}
    val_losses = {str(k):[] for k in LAMBDAS}
    for lambda_ in LAMBDAS:
        print_("Trying lambda=", lambda_)        

        device = torch.device('cuda' if USE_CUDA else 'cpu')
        model = model_getter().to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=LR)
        criterion = torch.nn.CrossEntropyLoss()

        lam_rs = lambda_.reshape((-1, 1, 1, 1, 1))
        lam_rs_tensor = torch.from_numpy(lam_rs).float().to(device)

        NMIX = lam_rs_tensor.shape[0]
        print_("Performing n-mixup with N-mix:", NMIX)
        first_batch = None

        # Train mode
        model.train()
        for epoch in range(1, N_EPOCHS + 1):
            for phase in ["train", "val"]:
                print_("Epoch[{}/{}]".format(epoch, N_EPOCHS))
                for batch_id, (images, labels) in enumerate(trainloader):
                    if N_BATCHES and batch_id > N_BATCHES:
                        break
                    labels, images = labels.to(device), images.to(device)
                    images_mx, ys, perms = utils.mixup_data_nmix(NMIX, images, labels, lam_rs_tensor)
                    outputs = model(images_mx)
                    loss = utils.mixup_criterion_nmix(criterion, outputs, ys, lam_rs_tensor)
                    loss_value = loss.item()

                    if first_batch is None:
                        print_('val loss:{:.4f} Epoch[{}/{}] Batch[{}/{}]'.format(
                                loss_value, epoch, N_EPOCHS, batch_id, N_BATCHES_IN_TRAIN_SET))
                        first_batch = images                    
                        print_("Batch shape:", first_batch.shape)
                        val_losses[str(lambda_)].append(loss_value)

                    optimizer.zero_grad()
                    if phase == "train":
                        loss.backward()
                        optimizer.step()
                        train_losses[str(lambda_)].append(loss_value)
                        if batch_id % 50 == 0:
                            print_(phase + ' loss:{:.4f} Epoch[{}/{}] Batch[{}/{}]'.format(
                                loss_value, epoch, N_EPOCHS, batch_id, N_BATCHES_IN_TRAIN_SET))
                    elif phase == "val":
                        print_(phase + ' loss:{:.4f} Epoch[{}/{}] Batch[{}/{}]'.format(
                                loss_value, epoch, N_EPOCHS, batch_id, N_BATCHES_IN_TRAIN_SET))
                        val_losses[str(lambda_)].append(loss_value)
                        break

        # Test mode
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in testloader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                predicted = torch.argmax(outputs, dim=1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            # Output test accuracy
            test_acc = 100 * correct / total
            print_('Test Accuracy of the model on the test images: {} %'.format(test_acc))
            test_accs[str(lambda_)] = test_acc


        del device, model, optimizer, criterion

perform_experiment()
# Out:
# [array([1., 0.]), array([0.875, 0.125]), array([0.75, 0.25]), array([0.625, 0.375]), array([0.5, 0.5])]
# Trying lambda= [1. 0.]
# Performing n-mixup with N-mix: 2
# Epoch[1/5]
# val loss:2.3348 Epoch[1/5] Batch[0/600]
# Batch shape: torch.Size([100, 1, 28, 28])
# train loss:2.3348 Epoch[1/5] Batch[0/600]
# Epoch[1/5]
# val loss:1.1240 Epoch[1/5] Batch[0/600]
# Epoch[2/5]
# train loss:0.9916 Epoch[2/5] Batch[0/600]
# Epoch[2/5]
# val loss:0.8550 Epoch[2/5] Batch[0/600]
# Epoch[3/5]
# train loss:0.7590 Epoch[3/5] Batch[0/600]
# Epoch[3/5]
# val loss:0.6234 Epoch[3/5] Batch[0/600]
# Epoch[4/5]
# train loss:0.8592 Epoch[4/5] Batch[0/600]
# Epoch[4/5]
# val loss:0.5595 Epoch[4/5] Batch[0/600]
# Epoch[5/5]
# train loss:0.7325 Epoch[5/5] Batch[0/600]
# Epoch[5/5]
# val loss:0.6582 Epoch[5/5] Batch[0/600]
# Test Accuracy of the model on the test images: 74.8 %
# Trying lambda= [0.875 0.125]
# Performing n-mixup with N-mix: 2
# Epoch[1/5]
# val loss:2.5701 Epoch[1/5] Batch[0/600]
# Batch shape: torch.Size([100, 1, 28, 28])
# train loss:2.5701 Epoch[1/5] Batch[0/600]
# Epoch[1/5]
# val loss:1.3660 Epoch[1/5] Batch[0/600]
# Epoch[2/5]
# train loss:1.3715 Epoch[2/5] Batch[0/600]
# Epoch[2/5]
# val loss:1.2313 Epoch[2/5] Batch[0/600]
# Epoch[3/5]
# train loss:1.2748 Epoch[3/5] Batch[0/600]
# Epoch[3/5]
# val loss:1.1905 Epoch[3/5] Batch[0/600]
# Epoch[4/5]
# train loss:1.1114 Epoch[4/5] Batch[0/600]
# Epoch[4/5]
# val loss:1.1819 Epoch[4/5] Batch[0/600]
# Epoch[5/5]
# train loss:1.1131 Epoch[5/5] Batch[0/600]
# Epoch[5/5]
# val loss:0.9676 Epoch[5/5] Batch[0/600]
# Test Accuracy of the model on the test images: 77.59 %
# Trying lambda= [0.75 0.25]
# Performing n-mixup with N-mix: 2
# Epoch[1/5]
# val loss:2.5562 Epoch[1/5] Batch[0/600]
# Batch shape: torch.Size([100, 1, 28, 28])
# train loss:2.5562 Epoch[1/5] Batch[0/600]
# Epoch[1/5]
# val loss:1.8518 Epoch[1/5] Batch[0/600]
# Epoch[2/5]
# train loss:1.8145 Epoch[2/5] Batch[0/600]
# Epoch[2/5]
# val loss:1.5478 Epoch[2/5] Batch[0/600]
# Epoch[3/5]
# train loss:1.4794 Epoch[3/5] Batch[0/600]
# Epoch[3/5]
# val loss:1.3890 Epoch[3/5] Batch[0/600]
# Epoch[4/5]
# train loss:1.4631 Epoch[4/5] Batch[0/600]
# Epoch[4/5]
# val loss:1.3071 Epoch[4/5] Batch[0/600]
# Epoch[5/5]
# train loss:1.3344 Epoch[5/5] Batch[0/600]
# Epoch[5/5]
# val loss:1.4605 Epoch[5/5] Batch[0/600]
# Test Accuracy of the model on the test images: 71.98 %
# Trying lambda= [0.625 0.375]
# Performing n-mixup with N-mix: 2
# Epoch[1/5]
# val loss:2.4647 Epoch[1/5] Batch[0/600]
# Batch shape: torch.Size([100, 1, 28, 28])
# train loss:2.4647 Epoch[1/5] Batch[0/600]
# Epoch[1/5]
# val loss:1.7172 Epoch[1/5] Batch[0/600]
# Epoch[2/5]
# train loss:1.7861 Epoch[2/5] Batch[0/600]
# Epoch[2/5]
# val loss:1.5879 Epoch[2/5] Batch[0/600]
# Epoch[3/5]
# train loss:1.5914 Epoch[3/5] Batch[0/600]
# Epoch[3/5]
# val loss:1.4974 Epoch[3/5] Batch[0/600]
# Epoch[4/5]
# train loss:1.5939 Epoch[4/5] Batch[0/600]
# Epoch[4/5]
# val loss:1.4233 Epoch[4/5] Batch[0/600]
# Epoch[5/5]
# train loss:1.4687 Epoch[5/5] Batch[0/600]
# Epoch[5/5]
# val loss:1.4245 Epoch[5/5] Batch[0/600]
# Test Accuracy of the model on the test images: 73.66 %
# Trying lambda= [0.5 0.5]
# Performing n-mixup with N-mix: 2
# Epoch[1/5]
# val loss:2.4470 Epoch[1/5] Batch[0/600]
# Batch shape: torch.Size([100, 1, 28, 28])
# train loss:2.4470 Epoch[1/5] Batch[0/600]
# Epoch[1/5]
# val loss:1.8854 Epoch[1/5] Batch[0/600]
# Epoch[2/5]
# train loss:1.9001 Epoch[2/5] Batch[0/600]
# Epoch[2/5]
# val loss:1.6582 Epoch[2/5] Batch[0/600]
# Epoch[3/5]
# train loss:1.6492 Epoch[3/5] Batch[0/600]
# Epoch[3/5]
# val loss:1.5225 Epoch[3/5] Batch[0/600]
# Epoch[4/5]
# train loss:1.6142 Epoch[4/5] Batch[0/600]
# Epoch[4/5]
# val loss:1.5143 Epoch[4/5] Batch[0/600]
# Epoch[5/5]
# train loss:1.4834 Epoch[5/5] Batch[0/600]
# Epoch[5/5]
# val loss:1.4304 Epoch[5/5] Batch[0/600]
# Test Accuracy of the model on the test images: 71.99 %

# %%
fig, axes = plt.subplots(1, 8, figsize=(15, 2))
for i in range(8):
    utils.show_np_arr(images_mx[i].cpu()[0, :, :], ax=axes[i])
    axes[i].set_title(trainset.classes[ys[0][i]]+" + "+trainset.classes[ys[1][i]], fontsize=10)
    pass

# %%
test_accs
# Out:
# {'[1. 0.]': 85.55, '[0.75 0.25]': 85.15, '[0.5 0.5]': 84.04}

# %%
plt.plot(train_losses['[1. 0.]'])
plt.plot([i*600 for i in range(0, len(val_losses['[1. 0.]']))], val_losses['[1. 0.]'])

# %%
plt.plot(train_losses['[0.75 0.25]'])
plt.plot([i*600 for i in range(0, len(val_losses['[0.75 0.25]']))], val_losses['[0.75 0.25]'])

# %%
plt.plot(train_losses['[0.5 0.5]'])
plt.plot([i*600 for i in range(0, len(val_losses['[0.5 0.5]']))], val_losses['[0.5 0.5]'])

# %% [markdown]
# ## N=3

# %%
USE_CUDA = True
RESULTS_FNAME = "delete"
N_EPOCHS = 5
N_BATCHES = 5
LR = 0.001
LAMBDAS = [np.array([1, 1/x, 1/(x*x)]) for x in np.linspace(1., 5., 4)]
LAMBDAS.append(np.array([1, 0, 0]))
LAMBDAS = [l / l.sum() for l in LAMBDAS]
print(LAMBDAS)
LAMBDAS2 = [np.array([lam, 1-lam]) for lam in np.linspace(1., .5, 5)]
LAMBDAS2 = [np.array([lam, (1-lam)*lam2[0], (1-lam)*lam2[1]]) for lam, lam2 in zip(np.linspace(1., .5, 5), LAMBDAS2)]
LAMBDAS2 = [l / l.sum() for l in LAMBDAS2]
print(LAMBDAS2)

print_ = utils.get_print(True, fname=RESULTS_FNAME)
model_getter = exp_models.CNN
# Out:
# [array([0.33333333, 0.33333333, 0.33333333]), array([0.62025316, 0.26582278, 0.11392405]), array([0.74233129, 0.20245399, 0.05521472]), array([0.80645161, 0.16129032, 0.03225806]), array([1., 0., 0.])]
# [array([1., 0., 0.]), array([0.875   , 0.109375, 0.015625]), array([0.75  , 0.1875, 0.0625]), array([0.625   , 0.234375, 0.140625]), array([0.5 , 0.25, 0.25])]
