# %%
import numpy as np
import torch
import torchvision
import PIL
import matplotlib.pyplot as plt
import utils
import exp_models

# %%
# Reproducibility
SEED = 2019

np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True

# %%
BATCH_SIZE = 100
NUM_WORKERS = 8

transform = torchvision.transforms.transforms.Compose([
    torchvision.transforms.transforms.ToTensor()
])

trainset = torchvision.datasets.CIFAR10(root='/data/landelle/datasets', train=True, download=True, transform=transform)
testset = torchvision.datasets.CIFAR10(root='/data/landelle/datasets', train=False, download=True, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
BATCH_SIZE = 100
N_BATCHES_IN_TRAIN_SET = len(trainset) // BATCH_SIZE
N_BATCHES_IN_TEST_SET = len(testset) // BATCH_SIZE
NUM_WORKERS = 8

trainloader = torch.utils.data.DataLoader(trainset, batch_size=BATCH_SIZE, shuffle=True, num_workers=NUM_WORKERS)
testloader = torch.utils.data.DataLoader(testset, batch_size=BATCH_SIZE, shuffle=False, num_workers=NUM_WORKERS)

# %%
def pixelgraft_data(X, y, pr, device):
    """
    Mixes data n ways with itself shuffled without overlaps, returns X_mixed and an array of every y shuffling
    Example:
        mixup_data(3, X, y, (.5, .5, 0)) will return X_mixed, y[permutation0], y[permutation1], y[permutation2]
        and X_mixed will veriy X_mixed = .5*X[permutation0] + .5*X[permutation1] + 0*X[permutation2]
    X: tensor of shape (batch_size, w, h, 3)
    y: tensor of shape (batch_size,)
    lam_: tensor of shape (n_ways, 1, 1, 1, 1)
    """
    assert X.shape[0] == y.shape[0]
    assert 0 <= pr <= 1
    perms = utils.no_overlap_perms_random(2, X.shape[0])
    #print(perms)
    X_permutations = torch.stack([X[perm] for perm in perms], 0)
    
    # compute the amount of pixels in image
    img_flat_size = X.shape[2] * X.shape[3]
    #print(img_flat_size)
    
    # create a mask that select 100pr% pixels of image 0 and 100(1-pr)% of image 1.
    graft_idx = (torch.rand(img_flat_size).to(device) < pr).int()
    
    #print(graft_idx)
    #print(1-graft_idx)
    
    #print(X_permutations.shape)
    
    lam_ = torch.stack((graft_idx, 1-graft_idx))
    lam_ = lam_.reshape((2, 1, 1, 32, 32)).float()
    #print(lam_)
    
    X_mixed = (X_permutations * lam_).sum(axis=0)
    ys = [y[perm] for perm in perms]
    
    #print(X_mixed)
    return X_mixed, ys, perms

# %%
USE_CUDA = True
device = torch.device('cuda' if USE_CUDA else 'cpu')

pr = .75

for batch_id, (images, labels) in enumerate(trainloader):
    if batch_id == 0:
        X_graft, ys, perms = pixelgraft_data(images.to(device), labels.to(device), pr, device)
        break
    

fig, axes = plt.subplots(3, 3, figsize=(10, 10))
plt.tight_layout(pad=2)
for j in range(3):
    for i in range(3):
        utils.show_np_arr(X_graft.cpu()[j*3+i], ax=axes[j, i])
        axes[j, i].set_title(str(pr)[:4] + "%" + trainset.classes[ys[0][j*3+i]] + "," +
                          str(1-pr)[:4] + "%" + trainset.classes[ys[1][j*3+i]], rotation=0)

# %%
USE_CUDA = True
N_EPOCHS = 100
N_BATCHES = None
LR = 0.001

model_getter = exp_models.resnet18


def perform_experiment(prs):
    print("saving results in", RESULTS_FNAME)
    print_ = utils.get_print(True, fname=RESULTS_FNAME)
    test_accs = {}
    train_losses = {str(k):[] for k in prs}
    val_losses = {str(k):[] for k in prs}
    
    for pr in prs:
        print_("Trying pr=", pr) 

        device = torch.device('cuda' if USE_CUDA else 'cpu')
        model = model_getter().to(device)
        optimizer = torch.optim.Adam(model.parameters(), lr=LR)
        criterion = torch.nn.CrossEntropyLoss()
        
        pr_rs_tensor = torch.Tensor([pr, 1-pr]).reshape((2, 1, 1, 1, 1)).to(device)

        # Train mode
        model.train()
        for epoch in range(1, N_EPOCHS + 1):
            # Training on all batches
            print_("Epoch[{}/{}]".format(epoch, N_EPOCHS))
            for batch_id, (images, labels) in enumerate(trainloader):
                if N_BATCHES and batch_id > N_BATCHES:
                    break
                labels, images = labels.to(device), images.to(device)
                images_mx, ys, perms = pixelgraft_data(images, labels, pr, device)
                outputs = model(images_mx)
                loss = utils.mixup_criterion_nmix(criterion, outputs, ys, pr_rs_tensor)
                loss_value = loss.item()

                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                train_losses[str(pr)].append(loss_value)
                if batch_id % 50 == 0:
                    print_('train loss:{:.4f} Epoch[{}/{}] Batch[{}/{}]'.format(
                        loss_value, epoch, N_EPOCHS, batch_id, N_BATCHES_IN_TRAIN_SET))
                    
            # Validating on one batch
            for images, labels in testloader:
                correct = 0
                total = 0
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                predicted = torch.argmax(outputs, dim=1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
                val_acc = 100 * correct / total
                loss = utils.mixup_criterion_nmix(criterion, outputs, ys, pr_rs_tensor)
                loss_value = loss.item()

                print_('val loss:{:.4f} Epoch[{}/{}]'.format(
                        loss_value, epoch, N_EPOCHS))
                print_('val acc:{:.4f} Epoch[{}/{}]'.format(
                        val_acc, epoch, N_EPOCHS))
                val_losses[str(pr)].append(loss_value)
                break

        # Test mode
        model.eval()
        with torch.no_grad():
            correct = 0
            total = 0
            for images, labels in testloader:
                images = images.to(device)
                labels = labels.to(device)
                outputs = model(images)
                predicted = torch.argmax(outputs, dim=1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()
            # Output test accuracy
            test_acc = 100 * correct / total
            print_('Test Accuracy of the model on the test images: {} %'.format(test_acc))
            test_accs[str(pr)] = test_acc


        del device, model, optimizer, criterion
    return test_accs, train_losses, images_mx, ys

# %%
    
PRS = [.75, .5]
RESULTS_FNAME = "r_cf10_rn18_graft"    

with open("results/"+RESULTS_FNAME, "w"):pass
test_accs, train_losses, images_mx, ys = perform_experiment(PRS)

#print(RESULTS_FNAME, PRS)
# Out:
# saving results in r_cf10_rn18_graft
# Trying pr= 0.75
# Epoch[1/100]
# train loss:2.4569 Epoch[1/100] Batch[0/500]
# train loss:2.1613 Epoch[1/100] Batch[50/500]
# train loss:1.9587 Epoch[1/100] Batch[100/500]
# train loss:1.8801 Epoch[1/100] Batch[150/500]
# train loss:1.8967 Epoch[1/100] Batch[200/500]
# train loss:1.9410 Epoch[1/100] Batch[250/500]
# train loss:1.8523 Epoch[1/100] Batch[300/500]
# train loss:1.7212 Epoch[1/100] Batch[350/500]
# train loss:1.9002 Epoch[1/100] Batch[400/500]
# train loss:1.8949 Epoch[1/100] Batch[450/500]
# val loss:2.8849 Epoch[1/100]
# val acc:57.0000 Epoch[1/100]
# Epoch[2/100]
# train loss:1.7361 Epoch[2/100] Batch[0/500]
# train loss:1.6648 Epoch[2/100] Batch[50/500]
# train loss:1.7661 Epoch[2/100] Batch[100/500]
# train loss:1.8230 Epoch[2/100] Batch[150/500]
# train loss:1.6858 Epoch[2/100] Batch[200/500]
# train loss:1.8114 Epoch[2/100] Batch[250/500]
# train loss:1.7069 Epoch[2/100] Batch[300/500]
# train loss:1.7293 Epoch[2/100] Batch[350/500]
# train loss:1.6865 Epoch[2/100] Batch[400/500]
# train loss:1.5590 Epoch[2/100] Batch[450/500]
# val loss:2.9253 Epoch[2/100]
# val acc:63.0000 Epoch[2/100]
# Epoch[3/100]
# train loss:1.6379 Epoch[3/100] Batch[0/500]
# train loss:1.6180 Epoch[3/100] Batch[50/500]
# train loss:1.6707 Epoch[3/100] Batch[100/500]
# train loss:1.8773 Epoch[3/100] Batch[150/500]
# train loss:1.6327 Epoch[3/100] Batch[200/500]
# train loss:1.6258 Epoch[3/100] Batch[250/500]
# train loss:1.6863 Epoch[3/100] Batch[300/500]
# train loss:1.5404 Epoch[3/100] Batch[350/500]
# train loss:1.7058 Epoch[3/100] Batch[400/500]
# train loss:1.5856 Epoch[3/100] Batch[450/500]
# val loss:3.3601 Epoch[3/100]
# val acc:71.0000 Epoch[3/100]
# Epoch[4/100]
# train loss:1.5120 Epoch[4/100] Batch[0/500]
# train loss:1.5296 Epoch[4/100] Batch[50/500]
# train loss:1.4426 Epoch[4/100] Batch[100/500]
# train loss:1.5784 Epoch[4/100] Batch[150/500]
# train loss:1.4505 Epoch[4/100] Batch[200/500]
# train loss:1.4774 Epoch[4/100] Batch[250/500]
# train loss:1.5311 Epoch[4/100] Batch[300/500]
# train loss:1.5552 Epoch[4/100] Batch[350/500]
# train loss:1.4936 Epoch[4/100] Batch[400/500]
# train loss:1.4152 Epoch[4/100] Batch[450/500]
# val loss:3.1154 Epoch[4/100]
# val acc:75.0000 Epoch[4/100]
# Epoch[5/100]
# train loss:1.4545 Epoch[5/100] Batch[0/500]
# train loss:1.4877 Epoch[5/100] Batch[50/500]
# train loss:1.5041 Epoch[5/100] Batch[100/500]
# train loss:1.5115 Epoch[5/100] Batch[150/500]
# train loss:1.4390 Epoch[5/100] Batch[200/500]
# train loss:1.3642 Epoch[5/100] Batch[250/500]
# train loss:1.4252 Epoch[5/100] Batch[300/500]
# train loss:1.3820 Epoch[5/100] Batch[350/500]
# train loss:1.5646 Epoch[5/100] Batch[400/500]
# train loss:1.4716 Epoch[5/100] Batch[450/500]
# val loss:3.4329 Epoch[5/100]
# val acc:76.0000 Epoch[5/100]
# Epoch[6/100]
# train loss:1.2675 Epoch[6/100] Batch[0/500]
# train loss:1.3119 Epoch[6/100] Batch[50/500]
# train loss:1.3843 Epoch[6/100] Batch[100/500]
# train loss:1.3485 Epoch[6/100] Batch[150/500]
# train loss:1.4109 Epoch[6/100] Batch[200/500]
# train loss:1.3754 Epoch[6/100] Batch[250/500]
# train loss:1.3268 Epoch[6/100] Batch[300/500]
# train loss:1.3937 Epoch[6/100] Batch[350/500]
# train loss:1.3532 Epoch[6/100] Batch[400/500]
# train loss:1.3556 Epoch[6/100] Batch[450/500]
# val loss:3.2563 Epoch[6/100]
# val acc:79.0000 Epoch[6/100]
# Epoch[7/100]
# train loss:1.4498 Epoch[7/100] Batch[0/500]
# train loss:1.3828 Epoch[7/100] Batch[50/500]
# train loss:1.3715 Epoch[7/100] Batch[100/500]
# train loss:1.3880 Epoch[7/100] Batch[150/500]
# train loss:1.4215 Epoch[7/100] Batch[200/500]
# train loss:1.3082 Epoch[7/100] Batch[250/500]
# train loss:1.3723 Epoch[7/100] Batch[300/500]
# train loss:1.3007 Epoch[7/100] Batch[350/500]
# train loss:1.4692 Epoch[7/100] Batch[400/500]
# train loss:1.2218 Epoch[7/100] Batch[450/500]
# val loss:3.4073 Epoch[7/100]
# val acc:86.0000 Epoch[7/100]
# Epoch[8/100]
# train loss:1.2168 Epoch[8/100] Batch[0/500]
# train loss:1.2895 Epoch[8/100] Batch[50/500]
# train loss:1.2924 Epoch[8/100] Batch[100/500]
# train loss:1.3896 Epoch[8/100] Batch[150/500]
# train loss:1.3489 Epoch[8/100] Batch[200/500]
# train loss:1.3752 Epoch[8/100] Batch[250/500]
# train loss:1.3222 Epoch[8/100] Batch[300/500]
# train loss:1.3614 Epoch[8/100] Batch[350/500]
# train loss:1.3193 Epoch[8/100] Batch[400/500]
# train loss:1.2447 Epoch[8/100] Batch[450/500]
# val loss:3.5120 Epoch[8/100]
# val acc:81.0000 Epoch[8/100]
# Epoch[9/100]
# train loss:1.2533 Epoch[9/100] Batch[0/500]
# train loss:1.3358 Epoch[9/100] Batch[50/500]
# train loss:1.3629 Epoch[9/100] Batch[100/500]
# train loss:1.2483 Epoch[9/100] Batch[150/500]
# train loss:1.2827 Epoch[9/100] Batch[200/500]
# train loss:1.3217 Epoch[9/100] Batch[250/500]
# train loss:1.2288 Epoch[9/100] Batch[300/500]
# train loss:1.1700 Epoch[9/100] Batch[350/500]
# train loss:1.3620 Epoch[9/100] Batch[400/500]
# train loss:1.2996 Epoch[9/100] Batch[450/500]
# val loss:3.4771 Epoch[9/100]
# val acc:82.0000 Epoch[9/100]
# Epoch[10/100]
# train loss:1.1159 Epoch[10/100] Batch[0/500]
# train loss:1.2843 Epoch[10/100] Batch[50/500]
# train loss:1.1801 Epoch[10/100] Batch[100/500]
# train loss:1.3105 Epoch[10/100] Batch[150/500]
# train loss:1.2232 Epoch[10/100] Batch[200/500]
# train loss:1.3119 Epoch[10/100] Batch[250/500]
# train loss:1.2425 Epoch[10/100] Batch[300/500]
# train loss:1.1794 Epoch[10/100] Batch[350/500]
# train loss:1.1763 Epoch[10/100] Batch[400/500]
# train loss:1.2259 Epoch[10/100] Batch[450/500]
# val loss:3.5318 Epoch[10/100]
# val acc:79.0000 Epoch[10/100]
# Epoch[11/100]
# train loss:1.2111 Epoch[11/100] Batch[0/500]
# train loss:1.3056 Epoch[11/100] Batch[50/500]
# train loss:1.1186 Epoch[11/100] Batch[100/500]
# train loss:1.1173 Epoch[11/100] Batch[150/500]
# train loss:1.2971 Epoch[11/100] Batch[200/500]
# train loss:1.1686 Epoch[11/100] Batch[250/500]
# train loss:1.2179 Epoch[11/100] Batch[300/500]
# train loss:1.1782 Epoch[11/100] Batch[350/500]
# train loss:1.2191 Epoch[11/100] Batch[400/500]
# train loss:1.0921 Epoch[11/100] Batch[450/500]
# val loss:3.5944 Epoch[11/100]
# val acc:80.0000 Epoch[11/100]
# Epoch[12/100]
# train loss:1.1941 Epoch[12/100] Batch[0/500]
# train loss:1.0259 Epoch[12/100] Batch[50/500]
# train loss:1.1041 Epoch[12/100] Batch[100/500]
# train loss:1.0911 Epoch[12/100] Batch[150/500]
# train loss:1.1589 Epoch[12/100] Batch[200/500]
# train loss:1.1774 Epoch[12/100] Batch[250/500]
# train loss:1.1407 Epoch[12/100] Batch[300/500]
# train loss:1.1388 Epoch[12/100] Batch[350/500]
# train loss:1.1732 Epoch[12/100] Batch[400/500]
# train loss:1.2237 Epoch[12/100] Batch[450/500]
# val loss:3.7342 Epoch[12/100]
# val acc:83.0000 Epoch[12/100]
# Epoch[13/100]
# train loss:1.1361 Epoch[13/100] Batch[0/500]
# train loss:1.1175 Epoch[13/100] Batch[50/500]
# train loss:1.1490 Epoch[13/100] Batch[100/500]
# train loss:1.0712 Epoch[13/100] Batch[150/500]
# train loss:1.0990 Epoch[13/100] Batch[200/500]
# train loss:1.1392 Epoch[13/100] Batch[250/500]
# train loss:1.1602 Epoch[13/100] Batch[300/500]
# train loss:1.0019 Epoch[13/100] Batch[350/500]
# train loss:1.1699 Epoch[13/100] Batch[400/500]
# train loss:1.1740 Epoch[13/100] Batch[450/500]
# val loss:3.8138 Epoch[13/100]
# val acc:81.0000 Epoch[13/100]
# Epoch[14/100]
# train loss:1.0899 Epoch[14/100] Batch[0/500]
# train loss:1.1185 Epoch[14/100] Batch[50/500]
# train loss:1.0891 Epoch[14/100] Batch[100/500]
# train loss:1.0762 Epoch[14/100] Batch[150/500]
# train loss:1.0718 Epoch[14/100] Batch[200/500]
# train loss:1.0863 Epoch[14/100] Batch[250/500]
# train loss:0.9675 Epoch[14/100] Batch[300/500]
# train loss:1.0780 Epoch[14/100] Batch[350/500]
# train loss:1.0358 Epoch[14/100] Batch[400/500]
# train loss:1.1637 Epoch[14/100] Batch[450/500]
# val loss:3.7019 Epoch[14/100]
# val acc:79.0000 Epoch[14/100]
# Epoch[15/100]
# train loss:1.0079 Epoch[15/100] Batch[0/500]
# train loss:1.0572 Epoch[15/100] Batch[50/500]
# train loss:1.0555 Epoch[15/100] Batch[100/500]
# train loss:1.0579 Epoch[15/100] Batch[150/500]
# train loss:1.1497 Epoch[15/100] Batch[200/500]
# train loss:1.0536 Epoch[15/100] Batch[250/500]
# train loss:1.1307 Epoch[15/100] Batch[300/500]
# train loss:1.0232 Epoch[15/100] Batch[350/500]
# train loss:1.0565 Epoch[15/100] Batch[400/500]
# train loss:1.0395 Epoch[15/100] Batch[450/500]
# val loss:3.9987 Epoch[15/100]
# val acc:83.0000 Epoch[15/100]
# Epoch[16/100]
# train loss:1.0409 Epoch[16/100] Batch[0/500]
# train loss:0.9608 Epoch[16/100] Batch[50/500]
# train loss:1.0410 Epoch[16/100] Batch[100/500]
# train loss:0.9811 Epoch[16/100] Batch[150/500]
# train loss:1.0176 Epoch[16/100] Batch[200/500]
# train loss:1.0957 Epoch[16/100] Batch[250/500]
# train loss:1.0583 Epoch[16/100] Batch[300/500]
# train loss:0.9736 Epoch[16/100] Batch[350/500]
# train loss:1.0368 Epoch[16/100] Batch[400/500]
# train loss:1.1091 Epoch[16/100] Batch[450/500]
# val loss:3.8461 Epoch[16/100]
# val acc:85.0000 Epoch[16/100]
# Epoch[17/100]
# train loss:0.9829 Epoch[17/100] Batch[0/500]
# train loss:0.9205 Epoch[17/100] Batch[50/500]
# train loss:1.0385 Epoch[17/100] Batch[100/500]
# train loss:1.0236 Epoch[17/100] Batch[150/500]
# train loss:0.9438 Epoch[17/100] Batch[200/500]
# train loss:0.9588 Epoch[17/100] Batch[250/500]
# train loss:1.0603 Epoch[17/100] Batch[300/500]
# train loss:0.9642 Epoch[17/100] Batch[350/500]
# train loss:1.0350 Epoch[17/100] Batch[400/500]
# train loss:0.9933 Epoch[17/100] Batch[450/500]
# val loss:4.2488 Epoch[17/100]
# val acc:81.0000 Epoch[17/100]
# Epoch[18/100]
# train loss:0.9066 Epoch[18/100] Batch[0/500]
# train loss:0.9566 Epoch[18/100] Batch[50/500]
# train loss:0.9610 Epoch[18/100] Batch[100/500]
# train loss:1.0177 Epoch[18/100] Batch[150/500]
# train loss:1.0548 Epoch[18/100] Batch[200/500]
# train loss:1.0350 Epoch[18/100] Batch[250/500]
# train loss:0.9600 Epoch[18/100] Batch[300/500]
# train loss:1.1133 Epoch[18/100] Batch[350/500]
# train loss:0.9671 Epoch[18/100] Batch[400/500]
# train loss:1.0415 Epoch[18/100] Batch[450/500]
# val loss:3.9582 Epoch[18/100]
# val acc:84.0000 Epoch[18/100]
# Epoch[19/100]
# train loss:1.0515 Epoch[19/100] Batch[0/500]
# train loss:1.0034 Epoch[19/100] Batch[50/500]
# train loss:0.9527 Epoch[19/100] Batch[100/500]
# train loss:0.9672 Epoch[19/100] Batch[150/500]
# train loss:0.9956 Epoch[19/100] Batch[200/500]
# train loss:0.9677 Epoch[19/100] Batch[250/500]
# train loss:1.0068 Epoch[19/100] Batch[300/500]
# train loss:0.9699 Epoch[19/100] Batch[350/500]
# train loss:1.0483 Epoch[19/100] Batch[400/500]
# train loss:0.9458 Epoch[19/100] Batch[450/500]
# val loss:4.3170 Epoch[19/100]
# val acc:91.0000 Epoch[19/100]
# Epoch[20/100]
# train loss:0.9315 Epoch[20/100] Batch[0/500]
# train loss:1.0054 Epoch[20/100] Batch[50/500]
# train loss:0.9627 Epoch[20/100] Batch[100/500]
# train loss:0.9761 Epoch[20/100] Batch[150/500]
# train loss:1.0054 Epoch[20/100] Batch[200/500]
# train loss:0.9984 Epoch[20/100] Batch[250/500]
# train loss:1.0016 Epoch[20/100] Batch[300/500]
# train loss:0.9796 Epoch[20/100] Batch[350/500]
# train loss:1.0231 Epoch[20/100] Batch[400/500]
# train loss:0.9351 Epoch[20/100] Batch[450/500]
# val loss:3.8358 Epoch[20/100]
# val acc:84.0000 Epoch[20/100]
# Epoch[21/100]
# train loss:1.0076 Epoch[21/100] Batch[0/500]
# train loss:1.0003 Epoch[21/100] Batch[50/500]
# train loss:0.9202 Epoch[21/100] Batch[100/500]
# train loss:0.9204 Epoch[21/100] Batch[150/500]
# train loss:0.9280 Epoch[21/100] Batch[200/500]
# train loss:0.9346 Epoch[21/100] Batch[250/500]
# train loss:0.8879 Epoch[21/100] Batch[300/500]
# train loss:0.9366 Epoch[21/100] Batch[350/500]
# train loss:0.9898 Epoch[21/100] Batch[400/500]
# train loss:0.8130 Epoch[21/100] Batch[450/500]
# val loss:3.9919 Epoch[21/100]
# val acc:85.0000 Epoch[21/100]
# Epoch[22/100]
# train loss:0.9900 Epoch[22/100] Batch[0/500]
# train loss:0.8727 Epoch[22/100] Batch[50/500]
# train loss:0.9450 Epoch[22/100] Batch[100/500]
# train loss:0.9829 Epoch[22/100] Batch[150/500]
# train loss:0.9566 Epoch[22/100] Batch[200/500]
# train loss:0.9303 Epoch[22/100] Batch[250/500]
# train loss:0.8953 Epoch[22/100] Batch[300/500]
# train loss:0.9547 Epoch[22/100] Batch[350/500]
# train loss:0.9074 Epoch[22/100] Batch[400/500]
# train loss:0.9612 Epoch[22/100] Batch[450/500]
# val loss:4.0650 Epoch[22/100]
# val acc:87.0000 Epoch[22/100]
# Epoch[23/100]
# train loss:0.8474 Epoch[23/100] Batch[0/500]
# train loss:0.9181 Epoch[23/100] Batch[50/500]
# train loss:0.9445 Epoch[23/100] Batch[100/500]
# train loss:0.8738 Epoch[23/100] Batch[150/500]
# train loss:0.9792 Epoch[23/100] Batch[200/500]
# train loss:0.9403 Epoch[23/100] Batch[250/500]
# train loss:0.9134 Epoch[23/100] Batch[300/500]
# train loss:0.8833 Epoch[23/100] Batch[350/500]
# train loss:0.9614 Epoch[23/100] Batch[400/500]
# train loss:0.9361 Epoch[23/100] Batch[450/500]
# val loss:4.1891 Epoch[23/100]
# val acc:80.0000 Epoch[23/100]
# Epoch[24/100]
# train loss:0.9018 Epoch[24/100] Batch[0/500]
# train loss:0.9248 Epoch[24/100] Batch[50/500]
# train loss:0.9669 Epoch[24/100] Batch[100/500]
# train loss:0.9588 Epoch[24/100] Batch[150/500]
# train loss:0.9220 Epoch[24/100] Batch[200/500]
# train loss:0.9017 Epoch[24/100] Batch[250/500]
# train loss:0.9634 Epoch[24/100] Batch[300/500]
# train loss:0.8514 Epoch[24/100] Batch[350/500]
# train loss:0.9561 Epoch[24/100] Batch[400/500]
# train loss:0.9028 Epoch[24/100] Batch[450/500]
# val loss:4.1875 Epoch[24/100]
# val acc:85.0000 Epoch[24/100]
# Epoch[25/100]
# train loss:0.8884 Epoch[25/100] Batch[0/500]
# train loss:0.8622 Epoch[25/100] Batch[50/500]
# train loss:0.8698 Epoch[25/100] Batch[100/500]
# train loss:0.9068 Epoch[25/100] Batch[150/500]
# train loss:0.9142 Epoch[25/100] Batch[200/500]
# train loss:0.9248 Epoch[25/100] Batch[250/500]
# train loss:0.9105 Epoch[25/100] Batch[300/500]
# train loss:0.9167 Epoch[25/100] Batch[350/500]
# train loss:0.8666 Epoch[25/100] Batch[400/500]
# train loss:0.9102 Epoch[25/100] Batch[450/500]
# val loss:4.3846 Epoch[25/100]
# val acc:83.0000 Epoch[25/100]
# Epoch[26/100]
# train loss:0.9669 Epoch[26/100] Batch[0/500]
# train loss:0.9129 Epoch[26/100] Batch[50/500]
# train loss:0.9963 Epoch[26/100] Batch[100/500]
# train loss:0.8738 Epoch[26/100] Batch[150/500]
# train loss:0.8924 Epoch[26/100] Batch[200/500]
# train loss:1.0167 Epoch[26/100] Batch[250/500]
# train loss:0.8874 Epoch[26/100] Batch[300/500]
# train loss:0.8906 Epoch[26/100] Batch[350/500]
# train loss:0.9168 Epoch[26/100] Batch[400/500]
# train loss:0.9781 Epoch[26/100] Batch[450/500]
# val loss:4.3052 Epoch[26/100]
# val acc:86.0000 Epoch[26/100]
# Epoch[27/100]
# train loss:0.8847 Epoch[27/100] Batch[0/500]
# train loss:0.9582 Epoch[27/100] Batch[50/500]
# train loss:0.8466 Epoch[27/100] Batch[100/500]
# train loss:0.8928 Epoch[27/100] Batch[150/500]
# train loss:0.8775 Epoch[27/100] Batch[200/500]
# train loss:0.9086 Epoch[27/100] Batch[250/500]
# train loss:0.9414 Epoch[27/100] Batch[300/500]
# train loss:0.8367 Epoch[27/100] Batch[350/500]
# train loss:0.8909 Epoch[27/100] Batch[400/500]
# train loss:0.9401 Epoch[27/100] Batch[450/500]
# val loss:4.3013 Epoch[27/100]
# val acc:89.0000 Epoch[27/100]
# Epoch[28/100]
# train loss:0.8903 Epoch[28/100] Batch[0/500]
# train loss:0.9164 Epoch[28/100] Batch[50/500]
# train loss:0.8558 Epoch[28/100] Batch[100/500]
# train loss:0.8963 Epoch[28/100] Batch[150/500]
# train loss:0.9436 Epoch[28/100] Batch[200/500]
# train loss:0.9294 Epoch[28/100] Batch[250/500]
# train loss:0.9108 Epoch[28/100] Batch[300/500]
# train loss:0.9497 Epoch[28/100] Batch[350/500]
# train loss:0.9304 Epoch[28/100] Batch[400/500]
# train loss:0.9428 Epoch[28/100] Batch[450/500]
# val loss:4.1556 Epoch[28/100]
# val acc:84.0000 Epoch[28/100]
# Epoch[29/100]
# train loss:0.8591 Epoch[29/100] Batch[0/500]
# train loss:0.9295 Epoch[29/100] Batch[50/500]
# train loss:0.9350 Epoch[29/100] Batch[100/500]
# train loss:0.8993 Epoch[29/100] Batch[150/500]
# train loss:0.9270 Epoch[29/100] Batch[200/500]
# train loss:0.8791 Epoch[29/100] Batch[250/500]
# train loss:0.8729 Epoch[29/100] Batch[300/500]
# train loss:0.9405 Epoch[29/100] Batch[350/500]
# train loss:0.9243 Epoch[29/100] Batch[400/500]
# train loss:0.9594 Epoch[29/100] Batch[450/500]
# val loss:4.4588 Epoch[29/100]
# val acc:86.0000 Epoch[29/100]
# Epoch[30/100]
# train loss:0.8392 Epoch[30/100] Batch[0/500]
# train loss:0.8770 Epoch[30/100] Batch[50/500]
# train loss:0.8503 Epoch[30/100] Batch[100/500]
# train loss:0.8121 Epoch[30/100] Batch[150/500]
# train loss:0.8636 Epoch[30/100] Batch[200/500]
# train loss:0.8963 Epoch[30/100] Batch[250/500]
# train loss:0.8984 Epoch[30/100] Batch[300/500]
# train loss:0.8396 Epoch[30/100] Batch[350/500]
# train loss:0.8964 Epoch[30/100] Batch[400/500]
# train loss:0.8393 Epoch[30/100] Batch[450/500]
# val loss:4.5887 Epoch[30/100]
# val acc:79.0000 Epoch[30/100]
# Epoch[31/100]
# train loss:0.8215 Epoch[31/100] Batch[0/500]
# train loss:0.8662 Epoch[31/100] Batch[50/500]
# train loss:0.8923 Epoch[31/100] Batch[100/500]
# train loss:0.9128 Epoch[31/100] Batch[150/500]
# train loss:0.8144 Epoch[31/100] Batch[200/500]
# train loss:0.8264 Epoch[31/100] Batch[250/500]
# train loss:0.8580 Epoch[31/100] Batch[300/500]
# train loss:0.8600 Epoch[31/100] Batch[350/500]
# train loss:0.8848 Epoch[31/100] Batch[400/500]
# train loss:0.8850 Epoch[31/100] Batch[450/500]
# val loss:4.4909 Epoch[31/100]
# val acc:85.0000 Epoch[31/100]
# Epoch[32/100]
# train loss:0.8836 Epoch[32/100] Batch[0/500]
# train loss:0.8298 Epoch[32/100] Batch[50/500]
# train loss:0.8959 Epoch[32/100] Batch[100/500]
# train loss:0.8768 Epoch[32/100] Batch[150/500]
# train loss:0.9246 Epoch[32/100] Batch[200/500]
# train loss:0.8790 Epoch[32/100] Batch[250/500]
# train loss:0.8796 Epoch[32/100] Batch[300/500]
# train loss:0.8776 Epoch[32/100] Batch[350/500]
# train loss:0.9136 Epoch[32/100] Batch[400/500]
# train loss:0.9364 Epoch[32/100] Batch[450/500]
# val loss:4.7303 Epoch[32/100]
# val acc:85.0000 Epoch[32/100]
# Epoch[33/100]
# train loss:0.8761 Epoch[33/100] Batch[0/500]
# train loss:0.8759 Epoch[33/100] Batch[50/500]
# train loss:0.8320 Epoch[33/100] Batch[100/500]
# train loss:0.8705 Epoch[33/100] Batch[150/500]
# train loss:0.8952 Epoch[33/100] Batch[200/500]
# train loss:0.9153 Epoch[33/100] Batch[250/500]
# train loss:0.8236 Epoch[33/100] Batch[300/500]
# train loss:0.8440 Epoch[33/100] Batch[350/500]
# train loss:0.8472 Epoch[33/100] Batch[400/500]
# train loss:0.9000 Epoch[33/100] Batch[450/500]
# val loss:4.3754 Epoch[33/100]
# val acc:83.0000 Epoch[33/100]
# Epoch[34/100]
# train loss:0.8258 Epoch[34/100] Batch[0/500]
# train loss:0.8904 Epoch[34/100] Batch[50/500]
# train loss:0.8658 Epoch[34/100] Batch[100/500]
# train loss:0.8240 Epoch[34/100] Batch[150/500]
# train loss:0.8516 Epoch[34/100] Batch[200/500]
# train loss:0.8266 Epoch[34/100] Batch[250/500]
# train loss:0.8351 Epoch[34/100] Batch[300/500]
# train loss:0.8619 Epoch[34/100] Batch[350/500]
# train loss:0.8581 Epoch[34/100] Batch[400/500]
# train loss:0.8618 Epoch[34/100] Batch[450/500]
# val loss:4.5878 Epoch[34/100]
# val acc:86.0000 Epoch[34/100]
# Epoch[35/100]
# train loss:0.8577 Epoch[35/100] Batch[0/500]
# train loss:0.8998 Epoch[35/100] Batch[50/500]
# train loss:0.8211 Epoch[35/100] Batch[100/500]
# train loss:0.8708 Epoch[35/100] Batch[150/500]
# train loss:0.7844 Epoch[35/100] Batch[200/500]
# train loss:0.8972 Epoch[35/100] Batch[250/500]
# train loss:0.8152 Epoch[35/100] Batch[300/500]
# train loss:0.8920 Epoch[35/100] Batch[350/500]
# train loss:0.8677 Epoch[35/100] Batch[400/500]
# train loss:0.8884 Epoch[35/100] Batch[450/500]
# val loss:4.5119 Epoch[35/100]
# val acc:82.0000 Epoch[35/100]
# Epoch[36/100]
# train loss:0.8259 Epoch[36/100] Batch[0/500]
# train loss:0.8034 Epoch[36/100] Batch[50/500]
# train loss:0.8306 Epoch[36/100] Batch[100/500]
# train loss:0.8958 Epoch[36/100] Batch[150/500]
# train loss:0.8732 Epoch[36/100] Batch[200/500]
# train loss:0.8508 Epoch[36/100] Batch[250/500]
# train loss:0.8852 Epoch[36/100] Batch[300/500]
# train loss:0.8540 Epoch[36/100] Batch[350/500]
# train loss:0.8680 Epoch[36/100] Batch[400/500]
# train loss:0.9031 Epoch[36/100] Batch[450/500]
# val loss:4.6508 Epoch[36/100]
# val acc:82.0000 Epoch[36/100]
# Epoch[37/100]
# train loss:0.8338 Epoch[37/100] Batch[0/500]
# train loss:0.8254 Epoch[37/100] Batch[50/500]
# train loss:0.8544 Epoch[37/100] Batch[100/500]
# train loss:0.8688 Epoch[37/100] Batch[150/500]
# train loss:0.8303 Epoch[37/100] Batch[200/500]
# train loss:0.8119 Epoch[37/100] Batch[250/500]
# train loss:0.8494 Epoch[37/100] Batch[300/500]
# train loss:0.8320 Epoch[37/100] Batch[350/500]
# train loss:0.8814 Epoch[37/100] Batch[400/500]
# train loss:0.8391 Epoch[37/100] Batch[450/500]
# val loss:4.4192 Epoch[37/100]
# val acc:82.0000 Epoch[37/100]
# Epoch[38/100]
# train loss:0.8561 Epoch[38/100] Batch[0/500]
# train loss:0.7969 Epoch[38/100] Batch[50/500]
# train loss:0.8495 Epoch[38/100] Batch[100/500]
# train loss:0.8297 Epoch[38/100] Batch[150/500]
# train loss:0.8452 Epoch[38/100] Batch[200/500]
# train loss:0.8800 Epoch[38/100] Batch[250/500]
# train loss:0.8933 Epoch[38/100] Batch[300/500]
# train loss:0.8273 Epoch[38/100] Batch[350/500]
# train loss:0.7726 Epoch[38/100] Batch[400/500]
# train loss:0.8572 Epoch[38/100] Batch[450/500]
# val loss:4.8243 Epoch[38/100]
# val acc:84.0000 Epoch[38/100]
# Epoch[39/100]
# train loss:0.8233 Epoch[39/100] Batch[0/500]
# train loss:0.8127 Epoch[39/100] Batch[50/500]
# train loss:0.8027 Epoch[39/100] Batch[100/500]
# train loss:0.7835 Epoch[39/100] Batch[150/500]
# train loss:0.8437 Epoch[39/100] Batch[200/500]
# train loss:0.8457 Epoch[39/100] Batch[250/500]
# train loss:0.8672 Epoch[39/100] Batch[300/500]
# train loss:0.8524 Epoch[39/100] Batch[350/500]
# train loss:0.8176 Epoch[39/100] Batch[400/500]
# train loss:0.8411 Epoch[39/100] Batch[450/500]
# val loss:4.7873 Epoch[39/100]
# val acc:87.0000 Epoch[39/100]
# Epoch[40/100]
# train loss:0.7984 Epoch[40/100] Batch[0/500]
# train loss:0.8359 Epoch[40/100] Batch[50/500]
# train loss:0.9119 Epoch[40/100] Batch[100/500]
# train loss:0.7620 Epoch[40/100] Batch[150/500]
# train loss:0.8314 Epoch[40/100] Batch[200/500]
# train loss:0.8651 Epoch[40/100] Batch[250/500]
# train loss:0.8703 Epoch[40/100] Batch[300/500]
# train loss:0.8253 Epoch[40/100] Batch[350/500]
# train loss:0.8246 Epoch[40/100] Batch[400/500]
# train loss:0.8132 Epoch[40/100] Batch[450/500]
# val loss:4.8687 Epoch[40/100]
# val acc:84.0000 Epoch[40/100]
# Epoch[41/100]
# train loss:0.7651 Epoch[41/100] Batch[0/500]
# train loss:0.8627 Epoch[41/100] Batch[50/500]
# train loss:0.8266 Epoch[41/100] Batch[100/500]
# train loss:0.8310 Epoch[41/100] Batch[150/500]
# train loss:0.8343 Epoch[41/100] Batch[200/500]
# train loss:0.8752 Epoch[41/100] Batch[250/500]
# train loss:0.8664 Epoch[41/100] Batch[300/500]
# train loss:0.8520 Epoch[41/100] Batch[350/500]
# train loss:0.8139 Epoch[41/100] Batch[400/500]
# train loss:0.8353 Epoch[41/100] Batch[450/500]
# val loss:4.5078 Epoch[41/100]
# val acc:88.0000 Epoch[41/100]
# Epoch[42/100]
# train loss:0.8139 Epoch[42/100] Batch[0/500]
# train loss:0.8456 Epoch[42/100] Batch[50/500]
# train loss:0.8522 Epoch[42/100] Batch[100/500]
# train loss:0.8699 Epoch[42/100] Batch[150/500]
# train loss:0.8421 Epoch[42/100] Batch[200/500]
# train loss:0.8417 Epoch[42/100] Batch[250/500]
# train loss:0.8344 Epoch[42/100] Batch[300/500]
# train loss:0.8164 Epoch[42/100] Batch[350/500]
# train loss:0.8223 Epoch[42/100] Batch[400/500]
# train loss:0.8370 Epoch[42/100] Batch[450/500]
# val loss:4.8118 Epoch[42/100]
# val acc:85.0000 Epoch[42/100]
# Epoch[43/100]
# train loss:0.7874 Epoch[43/100] Batch[0/500]
# train loss:0.8998 Epoch[43/100] Batch[50/500]
# train loss:0.8470 Epoch[43/100] Batch[100/500]
# train loss:0.7704 Epoch[43/100] Batch[150/500]
# train loss:0.7723 Epoch[43/100] Batch[200/500]
# train loss:0.7824 Epoch[43/100] Batch[250/500]
# train loss:0.8351 Epoch[43/100] Batch[300/500]
# train loss:0.8112 Epoch[43/100] Batch[350/500]
# train loss:0.8250 Epoch[43/100] Batch[400/500]
# train loss:0.8453 Epoch[43/100] Batch[450/500]
# val loss:4.5746 Epoch[43/100]
# val acc:84.0000 Epoch[43/100]
# Epoch[44/100]
# train loss:0.8088 Epoch[44/100] Batch[0/500]
# train loss:0.8154 Epoch[44/100] Batch[50/500]
# train loss:0.7961 Epoch[44/100] Batch[100/500]
# train loss:0.8406 Epoch[44/100] Batch[150/500]
# train loss:0.8878 Epoch[44/100] Batch[200/500]
# train loss:0.8752 Epoch[44/100] Batch[250/500]
# train loss:0.9291 Epoch[44/100] Batch[300/500]
# train loss:0.8107 Epoch[44/100] Batch[350/500]
# train loss:0.7887 Epoch[44/100] Batch[400/500]
# train loss:0.8276 Epoch[44/100] Batch[450/500]
# val loss:5.1135 Epoch[44/100]
# val acc:86.0000 Epoch[44/100]
# Epoch[45/100]
# train loss:0.8434 Epoch[45/100] Batch[0/500]
# train loss:0.8630 Epoch[45/100] Batch[50/500]
# train loss:0.8821 Epoch[45/100] Batch[100/500]
# train loss:0.8245 Epoch[45/100] Batch[150/500]
# train loss:0.7666 Epoch[45/100] Batch[200/500]
# train loss:0.8498 Epoch[45/100] Batch[250/500]
# train loss:0.8857 Epoch[45/100] Batch[300/500]
# train loss:0.8281 Epoch[45/100] Batch[350/500]
# train loss:0.7695 Epoch[45/100] Batch[400/500]
# train loss:0.8184 Epoch[45/100] Batch[450/500]
# val loss:4.6788 Epoch[45/100]
# val acc:85.0000 Epoch[45/100]
# Epoch[46/100]
# train loss:0.8768 Epoch[46/100] Batch[0/500]
# train loss:0.7352 Epoch[46/100] Batch[50/500]
# train loss:0.7602 Epoch[46/100] Batch[100/500]
# train loss:0.8118 Epoch[46/100] Batch[150/500]
# train loss:0.8401 Epoch[46/100] Batch[200/500]
# train loss:0.8146 Epoch[46/100] Batch[250/500]
# train loss:0.8494 Epoch[46/100] Batch[300/500]
# train loss:0.8284 Epoch[46/100] Batch[350/500]
# train loss:0.7586 Epoch[46/100] Batch[400/500]
# train loss:0.8262 Epoch[46/100] Batch[450/500]
# val loss:4.8918 Epoch[46/100]
# val acc:83.0000 Epoch[46/100]
# Epoch[47/100]
# train loss:0.7850 Epoch[47/100] Batch[0/500]
# train loss:0.7860 Epoch[47/100] Batch[50/500]
# train loss:0.8517 Epoch[47/100] Batch[100/500]
# train loss:0.7865 Epoch[47/100] Batch[150/500]
# train loss:0.7803 Epoch[47/100] Batch[200/500]
# train loss:0.8712 Epoch[47/100] Batch[250/500]
# train loss:0.8153 Epoch[47/100] Batch[300/500]
# train loss:0.8075 Epoch[47/100] Batch[350/500]
# train loss:0.8275 Epoch[47/100] Batch[400/500]
# train loss:0.8169 Epoch[47/100] Batch[450/500]
# val loss:5.1812 Epoch[47/100]
# val acc:86.0000 Epoch[47/100]
# Epoch[48/100]
# train loss:0.7990 Epoch[48/100] Batch[0/500]
# train loss:0.7662 Epoch[48/100] Batch[50/500]
# train loss:0.7712 Epoch[48/100] Batch[100/500]
# train loss:0.8275 Epoch[48/100] Batch[150/500]
# train loss:0.8019 Epoch[48/100] Batch[200/500]
# train loss:0.8856 Epoch[48/100] Batch[250/500]
# train loss:0.8137 Epoch[48/100] Batch[300/500]
# train loss:0.7889 Epoch[48/100] Batch[350/500]
# train loss:0.8283 Epoch[48/100] Batch[400/500]
# train loss:0.7899 Epoch[48/100] Batch[450/500]
# val loss:5.0517 Epoch[48/100]
# val acc:85.0000 Epoch[48/100]
# Epoch[49/100]
# train loss:0.8524 Epoch[49/100] Batch[0/500]
# train loss:0.8419 Epoch[49/100] Batch[50/500]
# train loss:0.8512 Epoch[49/100] Batch[100/500]
# train loss:0.7791 Epoch[49/100] Batch[150/500]
# train loss:0.8269 Epoch[49/100] Batch[200/500]
# train loss:0.7599 Epoch[49/100] Batch[250/500]
# train loss:0.8119 Epoch[49/100] Batch[300/500]
# train loss:0.8179 Epoch[49/100] Batch[350/500]
# train loss:0.8077 Epoch[49/100] Batch[400/500]
# train loss:0.8250 Epoch[49/100] Batch[450/500]
# val loss:4.7785 Epoch[49/100]
# val acc:89.0000 Epoch[49/100]
# Epoch[50/100]
# train loss:0.8235 Epoch[50/100] Batch[0/500]
# train loss:0.7794 Epoch[50/100] Batch[50/500]
# train loss:0.8072 Epoch[50/100] Batch[100/500]
# train loss:0.7499 Epoch[50/100] Batch[150/500]
# train loss:0.7842 Epoch[50/100] Batch[200/500]
# train loss:0.8157 Epoch[50/100] Batch[250/500]
# train loss:0.7981 Epoch[50/100] Batch[300/500]
# train loss:0.8162 Epoch[50/100] Batch[350/500]
# train loss:0.7681 Epoch[50/100] Batch[400/500]
# train loss:0.8100 Epoch[50/100] Batch[450/500]
# val loss:4.4833 Epoch[50/100]
# val acc:78.0000 Epoch[50/100]
# Epoch[51/100]
# train loss:0.7834 Epoch[51/100] Batch[0/500]
# train loss:0.8101 Epoch[51/100] Batch[50/500]
# train loss:0.8028 Epoch[51/100] Batch[100/500]
# train loss:0.8047 Epoch[51/100] Batch[150/500]
# train loss:0.8380 Epoch[51/100] Batch[200/500]
# train loss:0.8498 Epoch[51/100] Batch[250/500]
# train loss:0.8556 Epoch[51/100] Batch[300/500]
# train loss:0.7765 Epoch[51/100] Batch[350/500]
# train loss:0.7991 Epoch[51/100] Batch[400/500]
# train loss:0.7387 Epoch[51/100] Batch[450/500]
# val loss:4.7263 Epoch[51/100]
# val acc:87.0000 Epoch[51/100]
# Epoch[52/100]
# train loss:0.7809 Epoch[52/100] Batch[0/500]
# train loss:0.7494 Epoch[52/100] Batch[50/500]
# train loss:0.8011 Epoch[52/100] Batch[100/500]
# train loss:0.8027 Epoch[52/100] Batch[150/500]
# train loss:0.8238 Epoch[52/100] Batch[200/500]
# train loss:0.8501 Epoch[52/100] Batch[250/500]
# train loss:0.8028 Epoch[52/100] Batch[300/500]
# train loss:0.7865 Epoch[52/100] Batch[350/500]
# train loss:0.8407 Epoch[52/100] Batch[400/500]
# train loss:0.8114 Epoch[52/100] Batch[450/500]
# val loss:5.0346 Epoch[52/100]
# val acc:80.0000 Epoch[52/100]
# Epoch[53/100]
# train loss:0.8132 Epoch[53/100] Batch[0/500]
# train loss:0.8183 Epoch[53/100] Batch[50/500]
# train loss:0.8338 Epoch[53/100] Batch[100/500]
# train loss:0.8242 Epoch[53/100] Batch[150/500]
# train loss:0.8074 Epoch[53/100] Batch[200/500]
# train loss:0.8727 Epoch[53/100] Batch[250/500]
# train loss:0.8395 Epoch[53/100] Batch[300/500]
# train loss:0.8279 Epoch[53/100] Batch[350/500]
# train loss:0.7771 Epoch[53/100] Batch[400/500]
# train loss:0.7830 Epoch[53/100] Batch[450/500]
# val loss:4.9339 Epoch[53/100]
# val acc:86.0000 Epoch[53/100]
# Epoch[54/100]
# train loss:0.8206 Epoch[54/100] Batch[0/500]
# train loss:0.7435 Epoch[54/100] Batch[50/500]
# train loss:0.7517 Epoch[54/100] Batch[100/500]
# train loss:0.7281 Epoch[54/100] Batch[150/500]
# train loss:0.8258 Epoch[54/100] Batch[200/500]
# train loss:0.8237 Epoch[54/100] Batch[250/500]
# train loss:0.8057 Epoch[54/100] Batch[300/500]
# train loss:0.8013 Epoch[54/100] Batch[350/500]
# train loss:0.8323 Epoch[54/100] Batch[400/500]
# train loss:0.8496 Epoch[54/100] Batch[450/500]
# val loss:4.7525 Epoch[54/100]
# val acc:88.0000 Epoch[54/100]
# Epoch[55/100]
# train loss:0.8404 Epoch[55/100] Batch[0/500]
# train loss:0.7725 Epoch[55/100] Batch[50/500]
# train loss:0.7581 Epoch[55/100] Batch[100/500]
# train loss:0.8185 Epoch[55/100] Batch[150/500]
# train loss:0.7662 Epoch[55/100] Batch[200/500]
# train loss:0.8149 Epoch[55/100] Batch[250/500]
# train loss:0.7848 Epoch[55/100] Batch[300/500]
# train loss:0.8072 Epoch[55/100] Batch[350/500]
# train loss:0.7810 Epoch[55/100] Batch[400/500]
# train loss:0.8496 Epoch[55/100] Batch[450/500]
# val loss:5.2998 Epoch[55/100]
# val acc:86.0000 Epoch[55/100]
# Epoch[56/100]
# train loss:0.7558 Epoch[56/100] Batch[0/500]
# train loss:0.7570 Epoch[56/100] Batch[50/500]
# train loss:0.8135 Epoch[56/100] Batch[100/500]
# train loss:0.7588 Epoch[56/100] Batch[150/500]
# train loss:0.7795 Epoch[56/100] Batch[200/500]
# train loss:0.7537 Epoch[56/100] Batch[250/500]
# train loss:0.8496 Epoch[56/100] Batch[300/500]
# train loss:0.8254 Epoch[56/100] Batch[350/500]
# train loss:0.7427 Epoch[56/100] Batch[400/500]
# train loss:0.8030 Epoch[56/100] Batch[450/500]
# val loss:5.3984 Epoch[56/100]
# val acc:87.0000 Epoch[56/100]
# Epoch[57/100]
# train loss:0.7895 Epoch[57/100] Batch[0/500]
# train loss:0.7553 Epoch[57/100] Batch[50/500]
# train loss:0.7791 Epoch[57/100] Batch[100/500]
# train loss:0.8426 Epoch[57/100] Batch[150/500]
# train loss:0.8843 Epoch[57/100] Batch[200/500]
# train loss:0.7574 Epoch[57/100] Batch[250/500]
# train loss:0.7898 Epoch[57/100] Batch[300/500]
# train loss:0.7451 Epoch[57/100] Batch[350/500]
# train loss:0.7639 Epoch[57/100] Batch[400/500]
# train loss:0.7671 Epoch[57/100] Batch[450/500]
# val loss:4.8282 Epoch[57/100]
# val acc:84.0000 Epoch[57/100]
# Epoch[58/100]
# train loss:0.7509 Epoch[58/100] Batch[0/500]
# train loss:0.8128 Epoch[58/100] Batch[50/500]
# train loss:0.7188 Epoch[58/100] Batch[100/500]
# train loss:0.7712 Epoch[58/100] Batch[150/500]
# train loss:0.7792 Epoch[58/100] Batch[200/500]
# train loss:0.7570 Epoch[58/100] Batch[250/500]
# train loss:0.8125 Epoch[58/100] Batch[300/500]
# train loss:0.7806 Epoch[58/100] Batch[350/500]
# train loss:0.8103 Epoch[58/100] Batch[400/500]
# train loss:0.8435 Epoch[58/100] Batch[450/500]
# val loss:4.8767 Epoch[58/100]
# val acc:82.0000 Epoch[58/100]
# Epoch[59/100]
# train loss:0.7880 Epoch[59/100] Batch[0/500]
# train loss:0.7708 Epoch[59/100] Batch[50/500]
# train loss:0.7665 Epoch[59/100] Batch[100/500]
# train loss:0.7712 Epoch[59/100] Batch[150/500]
# train loss:0.7502 Epoch[59/100] Batch[200/500]
# train loss:0.8079 Epoch[59/100] Batch[250/500]
# train loss:0.7660 Epoch[59/100] Batch[300/500]
# train loss:0.7811 Epoch[59/100] Batch[350/500]
# train loss:0.7750 Epoch[59/100] Batch[400/500]
# train loss:0.7852 Epoch[59/100] Batch[450/500]
# val loss:5.2544 Epoch[59/100]
# val acc:87.0000 Epoch[59/100]
# Epoch[60/100]
# train loss:0.8051 Epoch[60/100] Batch[0/500]
# train loss:0.7586 Epoch[60/100] Batch[50/500]
# train loss:0.7960 Epoch[60/100] Batch[100/500]
# train loss:0.7504 Epoch[60/100] Batch[150/500]
# train loss:0.8035 Epoch[60/100] Batch[200/500]
# train loss:0.8279 Epoch[60/100] Batch[250/500]
# train loss:0.7987 Epoch[60/100] Batch[300/500]
# train loss:0.7901 Epoch[60/100] Batch[350/500]
# train loss:0.7872 Epoch[60/100] Batch[400/500]
# train loss:0.7471 Epoch[60/100] Batch[450/500]
# val loss:4.8985 Epoch[60/100]
# val acc:82.0000 Epoch[60/100]
# Epoch[61/100]
# train loss:0.7643 Epoch[61/100] Batch[0/500]
# train loss:0.7734 Epoch[61/100] Batch[50/500]
# train loss:0.7975 Epoch[61/100] Batch[100/500]
# train loss:0.7591 Epoch[61/100] Batch[150/500]
# train loss:0.8125 Epoch[61/100] Batch[200/500]
# train loss:0.7442 Epoch[61/100] Batch[250/500]
# train loss:0.7554 Epoch[61/100] Batch[300/500]
# train loss:0.7104 Epoch[61/100] Batch[350/500]
# train loss:0.7922 Epoch[61/100] Batch[400/500]
# train loss:0.7867 Epoch[61/100] Batch[450/500]
# val loss:5.3097 Epoch[61/100]
# val acc:81.0000 Epoch[61/100]
# Epoch[62/100]
# train loss:0.7667 Epoch[62/100] Batch[0/500]
# train loss:0.7528 Epoch[62/100] Batch[50/500]
# train loss:0.6944 Epoch[62/100] Batch[100/500]
# train loss:0.8154 Epoch[62/100] Batch[150/500]
# train loss:0.7203 Epoch[62/100] Batch[200/500]
# train loss:0.7283 Epoch[62/100] Batch[250/500]
# train loss:0.7517 Epoch[62/100] Batch[300/500]
# train loss:0.7981 Epoch[62/100] Batch[350/500]
# train loss:0.7460 Epoch[62/100] Batch[400/500]
# train loss:0.8252 Epoch[62/100] Batch[450/500]
# val loss:5.0087 Epoch[62/100]
# val acc:81.0000 Epoch[62/100]
# Epoch[63/100]
# train loss:0.7652 Epoch[63/100] Batch[0/500]
# train loss:0.7476 Epoch[63/100] Batch[50/500]
# train loss:0.7600 Epoch[63/100] Batch[100/500]
# train loss:0.7686 Epoch[63/100] Batch[150/500]
# train loss:0.7348 Epoch[63/100] Batch[200/500]
# train loss:0.7520 Epoch[63/100] Batch[250/500]
# train loss:0.7453 Epoch[63/100] Batch[300/500]
# train loss:0.7868 Epoch[63/100] Batch[350/500]
# train loss:0.7371 Epoch[63/100] Batch[400/500]
# train loss:0.7602 Epoch[63/100] Batch[450/500]
# val loss:5.3662 Epoch[63/100]
# val acc:82.0000 Epoch[63/100]
# Epoch[64/100]
# train loss:0.8098 Epoch[64/100] Batch[0/500]
# train loss:0.7244 Epoch[64/100] Batch[50/500]
# train loss:0.7800 Epoch[64/100] Batch[100/500]
# train loss:0.7354 Epoch[64/100] Batch[150/500]
# train loss:0.7442 Epoch[64/100] Batch[200/500]
# train loss:0.7457 Epoch[64/100] Batch[250/500]
# train loss:0.8087 Epoch[64/100] Batch[300/500]
# train loss:0.7465 Epoch[64/100] Batch[350/500]
# train loss:0.7957 Epoch[64/100] Batch[400/500]
# train loss:0.7205 Epoch[64/100] Batch[450/500]
# val loss:5.2189 Epoch[64/100]
# val acc:78.0000 Epoch[64/100]
# Epoch[65/100]
# train loss:0.7215 Epoch[65/100] Batch[0/500]
# train loss:0.7236 Epoch[65/100] Batch[50/500]
# train loss:0.7843 Epoch[65/100] Batch[100/500]
# train loss:0.7752 Epoch[65/100] Batch[150/500]
# train loss:0.8126 Epoch[65/100] Batch[200/500]
# train loss:0.7004 Epoch[65/100] Batch[250/500]
# train loss:0.7968 Epoch[65/100] Batch[300/500]
# train loss:0.8252 Epoch[65/100] Batch[350/500]
# train loss:0.7582 Epoch[65/100] Batch[400/500]
# train loss:0.8137 Epoch[65/100] Batch[450/500]
# val loss:5.2882 Epoch[65/100]
# val acc:81.0000 Epoch[65/100]
# Epoch[66/100]
# train loss:0.7861 Epoch[66/100] Batch[0/500]
# train loss:0.7538 Epoch[66/100] Batch[50/500]
# train loss:0.7333 Epoch[66/100] Batch[100/500]
# train loss:0.7460 Epoch[66/100] Batch[150/500]
# train loss:0.8073 Epoch[66/100] Batch[200/500]
# train loss:0.7259 Epoch[66/100] Batch[250/500]
# train loss:0.7568 Epoch[66/100] Batch[300/500]
# train loss:0.7384 Epoch[66/100] Batch[350/500]
# train loss:0.8609 Epoch[66/100] Batch[400/500]
# train loss:0.7234 Epoch[66/100] Batch[450/500]
# val loss:5.1109 Epoch[66/100]
# val acc:82.0000 Epoch[66/100]
# Epoch[67/100]
# train loss:0.7621 Epoch[67/100] Batch[0/500]
# train loss:0.7424 Epoch[67/100] Batch[50/500]
# train loss:0.6496 Epoch[67/100] Batch[100/500]
# train loss:0.7943 Epoch[67/100] Batch[150/500]
# train loss:0.7324 Epoch[67/100] Batch[200/500]
# train loss:0.8206 Epoch[67/100] Batch[250/500]
# train loss:0.7508 Epoch[67/100] Batch[300/500]
# train loss:0.8050 Epoch[67/100] Batch[350/500]
# train loss:0.7443 Epoch[67/100] Batch[400/500]
# train loss:0.7173 Epoch[67/100] Batch[450/500]
# val loss:5.4956 Epoch[67/100]
# val acc:82.0000 Epoch[67/100]
# Epoch[68/100]
# train loss:0.7327 Epoch[68/100] Batch[0/500]
# train loss:0.7262 Epoch[68/100] Batch[50/500]
# train loss:0.7527 Epoch[68/100] Batch[100/500]
# train loss:0.7550 Epoch[68/100] Batch[150/500]
# train loss:0.7783 Epoch[68/100] Batch[200/500]
# train loss:0.7927 Epoch[68/100] Batch[250/500]
# train loss:0.7564 Epoch[68/100] Batch[300/500]
# train loss:0.7889 Epoch[68/100] Batch[350/500]
# train loss:0.7400 Epoch[68/100] Batch[400/500]
# train loss:0.7925 Epoch[68/100] Batch[450/500]
# val loss:5.8267 Epoch[68/100]
# val acc:84.0000 Epoch[68/100]
# Epoch[69/100]
# train loss:0.7639 Epoch[69/100] Batch[0/500]
# train loss:0.7557 Epoch[69/100] Batch[50/500]
# train loss:0.7593 Epoch[69/100] Batch[100/500]
# train loss:0.7547 Epoch[69/100] Batch[150/500]
# train loss:0.7561 Epoch[69/100] Batch[200/500]
# train loss:0.7350 Epoch[69/100] Batch[250/500]
# train loss:0.7216 Epoch[69/100] Batch[300/500]
# train loss:0.8043 Epoch[69/100] Batch[350/500]
# train loss:0.7968 Epoch[69/100] Batch[400/500]
# train loss:0.7731 Epoch[69/100] Batch[450/500]
# val loss:5.2600 Epoch[69/100]
# val acc:80.0000 Epoch[69/100]
# Epoch[70/100]
# train loss:0.7096 Epoch[70/100] Batch[0/500]
# train loss:0.7787 Epoch[70/100] Batch[50/500]
# train loss:0.7573 Epoch[70/100] Batch[100/500]
# train loss:0.7674 Epoch[70/100] Batch[150/500]
# train loss:0.7158 Epoch[70/100] Batch[200/500]
# train loss:0.7563 Epoch[70/100] Batch[250/500]
# train loss:0.7665 Epoch[70/100] Batch[300/500]
# train loss:0.7113 Epoch[70/100] Batch[350/500]
# train loss:0.7124 Epoch[70/100] Batch[400/500]
# train loss:0.7889 Epoch[70/100] Batch[450/500]
# val loss:5.5622 Epoch[70/100]
# val acc:83.0000 Epoch[70/100]
# Epoch[71/100]
# train loss:0.7719 Epoch[71/100] Batch[0/500]
# train loss:0.7030 Epoch[71/100] Batch[50/500]
# train loss:0.7241 Epoch[71/100] Batch[100/500]
# train loss:0.7441 Epoch[71/100] Batch[150/500]
# train loss:0.7124 Epoch[71/100] Batch[200/500]
# train loss:0.7436 Epoch[71/100] Batch[250/500]
# train loss:0.7851 Epoch[71/100] Batch[300/500]
# train loss:0.7963 Epoch[71/100] Batch[350/500]
# train loss:0.7350 Epoch[71/100] Batch[400/500]
# train loss:0.7778 Epoch[71/100] Batch[450/500]
# val loss:5.9876 Epoch[71/100]
# val acc:82.0000 Epoch[71/100]
# Epoch[72/100]
# train loss:0.7192 Epoch[72/100] Batch[0/500]
# train loss:0.7570 Epoch[72/100] Batch[50/500]
# train loss:0.7561 Epoch[72/100] Batch[100/500]
# train loss:0.7718 Epoch[72/100] Batch[150/500]
# train loss:0.7750 Epoch[72/100] Batch[200/500]
# train loss:0.7292 Epoch[72/100] Batch[250/500]
# train loss:0.7516 Epoch[72/100] Batch[300/500]
# train loss:0.7768 Epoch[72/100] Batch[350/500]
# train loss:0.7433 Epoch[72/100] Batch[400/500]
# train loss:0.7785 Epoch[72/100] Batch[450/500]
# val loss:5.7469 Epoch[72/100]
# val acc:82.0000 Epoch[72/100]
# Epoch[73/100]
# train loss:0.7855 Epoch[73/100] Batch[0/500]
# train loss:0.7405 Epoch[73/100] Batch[50/500]
# train loss:0.7365 Epoch[73/100] Batch[100/500]
# train loss:0.8495 Epoch[73/100] Batch[150/500]
# train loss:0.7462 Epoch[73/100] Batch[200/500]
# train loss:0.8016 Epoch[73/100] Batch[250/500]
# train loss:0.7718 Epoch[73/100] Batch[300/500]
# train loss:0.6788 Epoch[73/100] Batch[350/500]
# train loss:0.7404 Epoch[73/100] Batch[400/500]
# train loss:0.7352 Epoch[73/100] Batch[450/500]
# val loss:5.4439 Epoch[73/100]
# val acc:82.0000 Epoch[73/100]
# Epoch[74/100]
# train loss:0.7655 Epoch[74/100] Batch[0/500]
# train loss:0.7501 Epoch[74/100] Batch[50/500]
# train loss:0.7466 Epoch[74/100] Batch[100/500]
# train loss:0.7543 Epoch[74/100] Batch[150/500]
# train loss:0.7342 Epoch[74/100] Batch[200/500]
# train loss:0.7938 Epoch[74/100] Batch[250/500]
# train loss:0.7555 Epoch[74/100] Batch[300/500]
# train loss:0.6872 Epoch[74/100] Batch[350/500]
# train loss:0.7041 Epoch[74/100] Batch[400/500]
# train loss:0.7450 Epoch[74/100] Batch[450/500]
# val loss:5.8474 Epoch[74/100]
# val acc:83.0000 Epoch[74/100]
# Epoch[75/100]
# train loss:0.7236 Epoch[75/100] Batch[0/500]
# train loss:0.7888 Epoch[75/100] Batch[50/500]
# train loss:0.6978 Epoch[75/100] Batch[100/500]
# train loss:0.7905 Epoch[75/100] Batch[150/500]
# train loss:0.7809 Epoch[75/100] Batch[200/500]
# train loss:0.7855 Epoch[75/100] Batch[250/500]
# train loss:0.7248 Epoch[75/100] Batch[300/500]
# train loss:0.7473 Epoch[75/100] Batch[350/500]
# train loss:0.6885 Epoch[75/100] Batch[400/500]
# train loss:0.7075 Epoch[75/100] Batch[450/500]
# val loss:5.7754 Epoch[75/100]
# val acc:82.0000 Epoch[75/100]
# Epoch[76/100]
# train loss:0.7707 Epoch[76/100] Batch[0/500]
# train loss:0.7189 Epoch[76/100] Batch[50/500]
# train loss:0.7081 Epoch[76/100] Batch[100/500]
# train loss:0.7585 Epoch[76/100] Batch[150/500]
# train loss:0.7398 Epoch[76/100] Batch[200/500]
# train loss:0.7737 Epoch[76/100] Batch[250/500]
# train loss:0.7697 Epoch[76/100] Batch[300/500]
# train loss:0.7765 Epoch[76/100] Batch[350/500]
# train loss:0.7390 Epoch[76/100] Batch[400/500]
# train loss:0.7462 Epoch[76/100] Batch[450/500]
# val loss:5.8604 Epoch[76/100]
# val acc:82.0000 Epoch[76/100]
# Epoch[77/100]
# train loss:0.7730 Epoch[77/100] Batch[0/500]
# train loss:0.6899 Epoch[77/100] Batch[50/500]
# train loss:0.7791 Epoch[77/100] Batch[100/500]
# train loss:0.7868 Epoch[77/100] Batch[150/500]
# train loss:0.6968 Epoch[77/100] Batch[200/500]
# train loss:0.7047 Epoch[77/100] Batch[250/500]
# train loss:0.7480 Epoch[77/100] Batch[300/500]
# train loss:0.7278 Epoch[77/100] Batch[350/500]
# train loss:0.7584 Epoch[77/100] Batch[400/500]
# train loss:0.7212 Epoch[77/100] Batch[450/500]
# val loss:5.6295 Epoch[77/100]
# val acc:84.0000 Epoch[77/100]
# Epoch[78/100]
# train loss:0.7359 Epoch[78/100] Batch[0/500]
# train loss:0.7579 Epoch[78/100] Batch[50/500]
# train loss:0.7151 Epoch[78/100] Batch[100/500]
# train loss:0.7160 Epoch[78/100] Batch[150/500]
# train loss:0.7469 Epoch[78/100] Batch[200/500]
# train loss:0.6859 Epoch[78/100] Batch[250/500]
# train loss:0.7250 Epoch[78/100] Batch[300/500]
# train loss:0.7077 Epoch[78/100] Batch[350/500]
# train loss:0.6971 Epoch[78/100] Batch[400/500]
# train loss:0.7687 Epoch[78/100] Batch[450/500]
# val loss:5.7666 Epoch[78/100]
# val acc:84.0000 Epoch[78/100]
# Epoch[79/100]
# train loss:0.7130 Epoch[79/100] Batch[0/500]
# train loss:0.7542 Epoch[79/100] Batch[50/500]
# train loss:0.7611 Epoch[79/100] Batch[100/500]
# train loss:0.6967 Epoch[79/100] Batch[150/500]
# train loss:0.7180 Epoch[79/100] Batch[200/500]
# train loss:0.7655 Epoch[79/100] Batch[250/500]
# train loss:0.7715 Epoch[79/100] Batch[300/500]
# train loss:0.7675 Epoch[79/100] Batch[350/500]
# train loss:0.7271 Epoch[79/100] Batch[400/500]
# train loss:0.8492 Epoch[79/100] Batch[450/500]
# val loss:5.9496 Epoch[79/100]
# val acc:84.0000 Epoch[79/100]
# Epoch[80/100]
# train loss:0.6511 Epoch[80/100] Batch[0/500]
# train loss:0.7642 Epoch[80/100] Batch[50/500]
# train loss:0.6831 Epoch[80/100] Batch[100/500]
# train loss:0.7171 Epoch[80/100] Batch[150/500]
# train loss:0.7144 Epoch[80/100] Batch[200/500]
# train loss:0.7435 Epoch[80/100] Batch[250/500]
# train loss:0.7285 Epoch[80/100] Batch[300/500]
# train loss:0.7731 Epoch[80/100] Batch[350/500]
# train loss:0.7015 Epoch[80/100] Batch[400/500]
# train loss:0.6896 Epoch[80/100] Batch[450/500]
# val loss:5.5456 Epoch[80/100]
# val acc:85.0000 Epoch[80/100]
# Epoch[81/100]
# train loss:0.7192 Epoch[81/100] Batch[0/500]
# train loss:0.7086 Epoch[81/100] Batch[50/500]
# train loss:0.7434 Epoch[81/100] Batch[100/500]
# train loss:0.7499 Epoch[81/100] Batch[150/500]
# train loss:0.7366 Epoch[81/100] Batch[200/500]
# train loss:0.7198 Epoch[81/100] Batch[250/500]
# train loss:0.6882 Epoch[81/100] Batch[300/500]
# train loss:0.7460 Epoch[81/100] Batch[350/500]
# train loss:0.6894 Epoch[81/100] Batch[400/500]
# train loss:0.7088 Epoch[81/100] Batch[450/500]
# val loss:5.8672 Epoch[81/100]
# val acc:84.0000 Epoch[81/100]
# Epoch[82/100]
# train loss:0.7066 Epoch[82/100] Batch[0/500]
# train loss:0.7306 Epoch[82/100] Batch[50/500]
# train loss:0.6907 Epoch[82/100] Batch[100/500]
# train loss:0.7685 Epoch[82/100] Batch[150/500]
# train loss:0.7192 Epoch[82/100] Batch[200/500]
# train loss:0.7625 Epoch[82/100] Batch[250/500]
# train loss:0.7412 Epoch[82/100] Batch[300/500]
# train loss:0.7127 Epoch[82/100] Batch[350/500]
# train loss:0.6831 Epoch[82/100] Batch[400/500]
# train loss:0.7710 Epoch[82/100] Batch[450/500]
# val loss:5.6479 Epoch[82/100]
# val acc:81.0000 Epoch[82/100]
# Epoch[83/100]
# train loss:0.6705 Epoch[83/100] Batch[0/500]
# train loss:0.7360 Epoch[83/100] Batch[50/500]
# train loss:0.7618 Epoch[83/100] Batch[100/500]
# train loss:0.7148 Epoch[83/100] Batch[150/500]
# train loss:0.6752 Epoch[83/100] Batch[200/500]
# train loss:0.6937 Epoch[83/100] Batch[250/500]
# train loss:0.7859 Epoch[83/100] Batch[300/500]
# train loss:0.7089 Epoch[83/100] Batch[350/500]
# train loss:0.7666 Epoch[83/100] Batch[400/500]
# train loss:0.6748 Epoch[83/100] Batch[450/500]
# val loss:5.8019 Epoch[83/100]
# val acc:82.0000 Epoch[83/100]
# Epoch[84/100]
# train loss:0.7860 Epoch[84/100] Batch[0/500]
# train loss:0.6564 Epoch[84/100] Batch[50/500]
# train loss:0.6621 Epoch[84/100] Batch[100/500]
# train loss:0.7249 Epoch[84/100] Batch[150/500]
# train loss:0.7264 Epoch[84/100] Batch[200/500]
# train loss:0.7046 Epoch[84/100] Batch[250/500]
# train loss:0.6961 Epoch[84/100] Batch[300/500]
# train loss:0.7742 Epoch[84/100] Batch[350/500]
# train loss:0.7176 Epoch[84/100] Batch[400/500]
# train loss:0.6907 Epoch[84/100] Batch[450/500]
# val loss:6.4436 Epoch[84/100]
# val acc:82.0000 Epoch[84/100]
# Epoch[85/100]
# train loss:0.6796 Epoch[85/100] Batch[0/500]
# train loss:0.7615 Epoch[85/100] Batch[50/500]
# train loss:0.6984 Epoch[85/100] Batch[100/500]
# train loss:0.6075 Epoch[85/100] Batch[150/500]
# train loss:0.7497 Epoch[85/100] Batch[200/500]
# train loss:0.6953 Epoch[85/100] Batch[250/500]
# train loss:0.6954 Epoch[85/100] Batch[300/500]
# train loss:0.7713 Epoch[85/100] Batch[350/500]
# train loss:0.6630 Epoch[85/100] Batch[400/500]
# train loss:0.6757 Epoch[85/100] Batch[450/500]
# val loss:5.5197 Epoch[85/100]
# val acc:84.0000 Epoch[85/100]
# Epoch[86/100]
# train loss:0.6611 Epoch[86/100] Batch[0/500]
# train loss:0.7283 Epoch[86/100] Batch[50/500]
# train loss:0.6983 Epoch[86/100] Batch[100/500]
# train loss:0.6828 Epoch[86/100] Batch[150/500]
# train loss:0.7194 Epoch[86/100] Batch[200/500]
# train loss:0.7532 Epoch[86/100] Batch[250/500]
# train loss:0.7141 Epoch[86/100] Batch[300/500]
# train loss:0.7389 Epoch[86/100] Batch[350/500]
# train loss:0.6522 Epoch[86/100] Batch[400/500]
# train loss:0.6939 Epoch[86/100] Batch[450/500]
# val loss:5.8481 Epoch[86/100]
# val acc:81.0000 Epoch[86/100]
# Epoch[87/100]
# train loss:0.6999 Epoch[87/100] Batch[0/500]
# train loss:0.6745 Epoch[87/100] Batch[50/500]
# train loss:0.7120 Epoch[87/100] Batch[100/500]
# train loss:0.6783 Epoch[87/100] Batch[150/500]
# train loss:0.6776 Epoch[87/100] Batch[200/500]
# train loss:0.7530 Epoch[87/100] Batch[250/500]
# train loss:0.6805 Epoch[87/100] Batch[300/500]
# train loss:0.6760 Epoch[87/100] Batch[350/500]
# train loss:0.7556 Epoch[87/100] Batch[400/500]
# train loss:0.7268 Epoch[87/100] Batch[450/500]
# val loss:6.1275 Epoch[87/100]
# val acc:80.0000 Epoch[87/100]
# Epoch[88/100]
# train loss:0.7435 Epoch[88/100] Batch[0/500]
# train loss:0.7225 Epoch[88/100] Batch[50/500]
# train loss:0.7590 Epoch[88/100] Batch[100/500]
# train loss:0.7775 Epoch[88/100] Batch[150/500]
# train loss:0.6930 Epoch[88/100] Batch[200/500]
# train loss:0.6779 Epoch[88/100] Batch[250/500]
# train loss:0.6702 Epoch[88/100] Batch[300/500]
# train loss:0.7322 Epoch[88/100] Batch[350/500]
# train loss:0.7211 Epoch[88/100] Batch[400/500]
# train loss:0.6964 Epoch[88/100] Batch[450/500]
# val loss:5.5970 Epoch[88/100]
# val acc:81.0000 Epoch[88/100]
# Epoch[89/100]
# train loss:0.7386 Epoch[89/100] Batch[0/500]
# train loss:0.7046 Epoch[89/100] Batch[50/500]
# train loss:0.6619 Epoch[89/100] Batch[100/500]
# train loss:0.7268 Epoch[89/100] Batch[150/500]
# train loss:0.6992 Epoch[89/100] Batch[200/500]
# train loss:0.6846 Epoch[89/100] Batch[250/500]
# train loss:0.6926 Epoch[89/100] Batch[300/500]
# train loss:0.7236 Epoch[89/100] Batch[350/500]
# train loss:0.7286 Epoch[89/100] Batch[400/500]
# ...
# train loss:0.9563 Epoch[71/100] Batch[350/500]
# train loss:1.0674 Epoch[71/100] Batch[400/500]
# train loss:1.0696 Epoch[71/100] Batch[450/500]
# val loss:5.7263 Epoch[71/100]
# val acc:81.0000 Epoch[71/100]
# Epoch[72/100]
# train loss:0.9516 Epoch[72/100] Batch[0/500]
# train loss:0.9785 Epoch[72/100] Batch[50/500]
# train loss:0.9284 Epoch[72/100] Batch[100/500]
# train loss:0.9701 Epoch[72/100] Batch[150/500]
# train loss:0.9414 Epoch[72/100] Batch[200/500]
# train loss:1.0957 Epoch[72/100] Batch[250/500]
# train loss:0.9196 Epoch[72/100] Batch[300/500]
# train loss:0.8411 Epoch[72/100] Batch[350/500]
# train loss:1.1387 Epoch[72/100] Batch[400/500]
# train loss:0.9902 Epoch[72/100] Batch[450/500]
# val loss:5.9085 Epoch[72/100]
# val acc:79.0000 Epoch[72/100]
# Epoch[73/100]
# train loss:0.9045 Epoch[73/100] Batch[0/500]
# train loss:0.9042 Epoch[73/100] Batch[50/500]
# train loss:0.9932 Epoch[73/100] Batch[100/500]
# train loss:0.9333 Epoch[73/100] Batch[150/500]
# train loss:0.9167 Epoch[73/100] Batch[200/500]
# train loss:0.9159 Epoch[73/100] Batch[250/500]
# train loss:0.8920 Epoch[73/100] Batch[300/500]
# train loss:1.0000 Epoch[73/100] Batch[350/500]
# train loss:0.9337 Epoch[73/100] Batch[400/500]
# train loss:1.0309 Epoch[73/100] Batch[450/500]
# val loss:5.4550 Epoch[73/100]
# val acc:84.0000 Epoch[73/100]
# Epoch[74/100]
# train loss:0.8909 Epoch[74/100] Batch[0/500]
# train loss:0.8873 Epoch[74/100] Batch[50/500]
# train loss:0.9026 Epoch[74/100] Batch[100/500]
# train loss:0.9016 Epoch[74/100] Batch[150/500]
# train loss:0.8976 Epoch[74/100] Batch[200/500]
# train loss:0.9248 Epoch[74/100] Batch[250/500]
# train loss:1.1076 Epoch[74/100] Batch[300/500]
# train loss:0.9266 Epoch[74/100] Batch[350/500]
# train loss:1.0787 Epoch[74/100] Batch[400/500]
# train loss:0.9411 Epoch[74/100] Batch[450/500]
# val loss:5.4985 Epoch[74/100]
# val acc:75.0000 Epoch[74/100]
# Epoch[75/100]
# train loss:0.9060 Epoch[75/100] Batch[0/500]
# train loss:0.9107 Epoch[75/100] Batch[50/500]
# train loss:0.9912 Epoch[75/100] Batch[100/500]
# train loss:0.9150 Epoch[75/100] Batch[150/500]
# train loss:0.8577 Epoch[75/100] Batch[200/500]
# train loss:1.0948 Epoch[75/100] Batch[250/500]
# train loss:0.9201 Epoch[75/100] Batch[300/500]
# train loss:1.0091 Epoch[75/100] Batch[350/500]
# train loss:0.8768 Epoch[75/100] Batch[400/500]
# train loss:0.9284 Epoch[75/100] Batch[450/500]
# val loss:6.0296 Epoch[75/100]
# val acc:81.0000 Epoch[75/100]
# Epoch[76/100]
# train loss:0.9034 Epoch[76/100] Batch[0/500]
# train loss:0.9457 Epoch[76/100] Batch[50/500]
# train loss:0.8614 Epoch[76/100] Batch[100/500]
# train loss:0.8562 Epoch[76/100] Batch[150/500]
# train loss:0.9804 Epoch[76/100] Batch[200/500]
# train loss:0.9610 Epoch[76/100] Batch[250/500]
# train loss:0.8889 Epoch[76/100] Batch[300/500]
# train loss:0.9525 Epoch[76/100] Batch[350/500]
# train loss:0.9982 Epoch[76/100] Batch[400/500]
# train loss:0.9835 Epoch[76/100] Batch[450/500]
# val loss:5.7157 Epoch[76/100]
# val acc:78.0000 Epoch[76/100]
# Epoch[77/100]
# train loss:0.9537 Epoch[77/100] Batch[0/500]
# train loss:0.9178 Epoch[77/100] Batch[50/500]
# train loss:1.0440 Epoch[77/100] Batch[100/500]
# train loss:0.9396 Epoch[77/100] Batch[150/500]
# train loss:0.9493 Epoch[77/100] Batch[200/500]
# train loss:0.9067 Epoch[77/100] Batch[250/500]
# train loss:0.8577 Epoch[77/100] Batch[300/500]
# train loss:0.9856 Epoch[77/100] Batch[350/500]
# train loss:0.9196 Epoch[77/100] Batch[400/500]
# train loss:0.9848 Epoch[77/100] Batch[450/500]
# val loss:5.8450 Epoch[77/100]
# val acc:78.0000 Epoch[77/100]
# Epoch[78/100]
# train loss:0.9397 Epoch[78/100] Batch[0/500]
# train loss:0.9622 Epoch[78/100] Batch[50/500]
# train loss:0.9264 Epoch[78/100] Batch[100/500]
# train loss:0.8630 Epoch[78/100] Batch[150/500]
# train loss:0.9867 Epoch[78/100] Batch[200/500]
# train loss:0.8677 Epoch[78/100] Batch[250/500]
# train loss:1.0315 Epoch[78/100] Batch[300/500]
# train loss:0.9215 Epoch[78/100] Batch[350/500]
# train loss:1.0209 Epoch[78/100] Batch[400/500]
# train loss:0.9318 Epoch[78/100] Batch[450/500]
# val loss:5.8435 Epoch[78/100]
# val acc:76.0000 Epoch[78/100]
# Epoch[79/100]
# train loss:0.8889 Epoch[79/100] Batch[0/500]
# train loss:1.0022 Epoch[79/100] Batch[50/500]
# train loss:0.8753 Epoch[79/100] Batch[100/500]
# train loss:0.8986 Epoch[79/100] Batch[150/500]
# train loss:0.9454 Epoch[79/100] Batch[200/500]
# train loss:0.8905 Epoch[79/100] Batch[250/500]
# train loss:0.8563 Epoch[79/100] Batch[300/500]
# train loss:0.8666 Epoch[79/100] Batch[350/500]
# train loss:0.9244 Epoch[79/100] Batch[400/500]
# train loss:0.8989 Epoch[79/100] Batch[450/500]
# val loss:5.9701 Epoch[79/100]
# val acc:77.0000 Epoch[79/100]
# Epoch[80/100]
# train loss:0.9777 Epoch[80/100] Batch[0/500]
# train loss:0.8928 Epoch[80/100] Batch[50/500]
# train loss:0.9081 Epoch[80/100] Batch[100/500]
# train loss:0.8685 Epoch[80/100] Batch[150/500]
# train loss:0.8929 Epoch[80/100] Batch[200/500]
# train loss:0.9334 Epoch[80/100] Batch[250/500]
# train loss:0.9691 Epoch[80/100] Batch[300/500]
# train loss:0.9844 Epoch[80/100] Batch[350/500]
# train loss:0.8695 Epoch[80/100] Batch[400/500]
# train loss:0.9552 Epoch[80/100] Batch[450/500]
# val loss:5.8797 Epoch[80/100]
# val acc:79.0000 Epoch[80/100]
# Epoch[81/100]
# train loss:0.9019 Epoch[81/100] Batch[0/500]
# train loss:0.9190 Epoch[81/100] Batch[50/500]
# train loss:0.8678 Epoch[81/100] Batch[100/500]
# train loss:0.9710 Epoch[81/100] Batch[150/500]
# train loss:0.9842 Epoch[81/100] Batch[200/500]
# train loss:0.8491 Epoch[81/100] Batch[250/500]
# train loss:1.0284 Epoch[81/100] Batch[300/500]
# train loss:0.8266 Epoch[81/100] Batch[350/500]
# train loss:0.9348 Epoch[81/100] Batch[400/500]
# train loss:0.9015 Epoch[81/100] Batch[450/500]
# val loss:5.8900 Epoch[81/100]
# val acc:81.0000 Epoch[81/100]
# Epoch[82/100]
# train loss:0.9344 Epoch[82/100] Batch[0/500]
# train loss:0.9446 Epoch[82/100] Batch[50/500]
# train loss:0.9621 Epoch[82/100] Batch[100/500]
# train loss:0.9604 Epoch[82/100] Batch[150/500]
# train loss:0.8846 Epoch[82/100] Batch[200/500]
# train loss:1.0869 Epoch[82/100] Batch[250/500]
# train loss:0.9279 Epoch[82/100] Batch[300/500]
# train loss:0.9404 Epoch[82/100] Batch[350/500]
# train loss:0.9732 Epoch[82/100] Batch[400/500]
# train loss:0.9300 Epoch[82/100] Batch[450/500]
# val loss:5.6685 Epoch[82/100]
# val acc:79.0000 Epoch[82/100]
# Epoch[83/100]
# train loss:0.9321 Epoch[83/100] Batch[0/500]
# train loss:0.9272 Epoch[83/100] Batch[50/500]
# train loss:1.0084 Epoch[83/100] Batch[100/500]
# train loss:0.9963 Epoch[83/100] Batch[150/500]
# train loss:0.8738 Epoch[83/100] Batch[200/500]
# train loss:0.9004 Epoch[83/100] Batch[250/500]
# train loss:0.7797 Epoch[83/100] Batch[300/500]
# train loss:0.9377 Epoch[83/100] Batch[350/500]
# train loss:0.9076 Epoch[83/100] Batch[400/500]
# train loss:0.9378 Epoch[83/100] Batch[450/500]
# val loss:5.8210 Epoch[83/100]
# val acc:82.0000 Epoch[83/100]
# Epoch[84/100]
# train loss:0.9768 Epoch[84/100] Batch[0/500]
# train loss:0.9382 Epoch[84/100] Batch[50/500]
# train loss:0.8570 Epoch[84/100] Batch[100/500]
# train loss:0.9550 Epoch[84/100] Batch[150/500]
# train loss:0.9856 Epoch[84/100] Batch[200/500]
# train loss:0.8287 Epoch[84/100] Batch[250/500]
# train loss:0.8900 Epoch[84/100] Batch[300/500]
# train loss:0.9703 Epoch[84/100] Batch[350/500]
# train loss:0.9614 Epoch[84/100] Batch[400/500]
# train loss:0.8870 Epoch[84/100] Batch[450/500]
# val loss:5.5663 Epoch[84/100]
# val acc:79.0000 Epoch[84/100]
# Epoch[85/100]
# train loss:0.8485 Epoch[85/100] Batch[0/500]
# train loss:0.9673 Epoch[85/100] Batch[50/500]
# train loss:0.8952 Epoch[85/100] Batch[100/500]
# train loss:0.9282 Epoch[85/100] Batch[150/500]
# train loss:0.9866 Epoch[85/100] Batch[200/500]
# train loss:0.9975 Epoch[85/100] Batch[250/500]
# train loss:0.9199 Epoch[85/100] Batch[300/500]
# train loss:1.0147 Epoch[85/100] Batch[350/500]
# train loss:0.9402 Epoch[85/100] Batch[400/500]
# train loss:0.9953 Epoch[85/100] Batch[450/500]
# val loss:6.1106 Epoch[85/100]
# val acc:79.0000 Epoch[85/100]
# Epoch[86/100]
# train loss:0.8430 Epoch[86/100] Batch[0/500]
# train loss:0.8814 Epoch[86/100] Batch[50/500]
# train loss:1.0254 Epoch[86/100] Batch[100/500]
# train loss:1.0048 Epoch[86/100] Batch[150/500]
# train loss:1.0303 Epoch[86/100] Batch[200/500]
# train loss:0.9969 Epoch[86/100] Batch[250/500]
# train loss:0.9669 Epoch[86/100] Batch[300/500]
# train loss:0.8515 Epoch[86/100] Batch[350/500]
# train loss:0.8687 Epoch[86/100] Batch[400/500]
# train loss:0.8734 Epoch[86/100] Batch[450/500]
# val loss:6.1272 Epoch[86/100]
# val acc:82.0000 Epoch[86/100]
# Epoch[87/100]
# train loss:0.9365 Epoch[87/100] Batch[0/500]
# train loss:0.9545 Epoch[87/100] Batch[50/500]
# train loss:0.8461 Epoch[87/100] Batch[100/500]
# train loss:0.9621 Epoch[87/100] Batch[150/500]
# train loss:0.9162 Epoch[87/100] Batch[200/500]
# train loss:0.8092 Epoch[87/100] Batch[250/500]
# train loss:0.9699 Epoch[87/100] Batch[300/500]
# train loss:0.9242 Epoch[87/100] Batch[350/500]
# train loss:0.9004 Epoch[87/100] Batch[400/500]
# train loss:0.9304 Epoch[87/100] Batch[450/500]
# val loss:5.9748 Epoch[87/100]
# val acc:82.0000 Epoch[87/100]
# Epoch[88/100]
# train loss:0.8179 Epoch[88/100] Batch[0/500]
# train loss:0.7928 Epoch[88/100] Batch[50/500]
# train loss:0.8665 Epoch[88/100] Batch[100/500]
# train loss:0.9134 Epoch[88/100] Batch[150/500]
# train loss:0.9298 Epoch[88/100] Batch[200/500]
# train loss:0.9688 Epoch[88/100] Batch[250/500]
# train loss:1.0202 Epoch[88/100] Batch[300/500]
# train loss:0.8721 Epoch[88/100] Batch[350/500]
# train loss:0.9386 Epoch[88/100] Batch[400/500]
# train loss:0.8565 Epoch[88/100] Batch[450/500]
# val loss:6.4693 Epoch[88/100]
# val acc:77.0000 Epoch[88/100]
# Epoch[89/100]
# train loss:0.8719 Epoch[89/100] Batch[0/500]
# train loss:0.8155 Epoch[89/100] Batch[50/500]
# train loss:0.9269 Epoch[89/100] Batch[100/500]
# train loss:0.8504 Epoch[89/100] Batch[150/500]
# train loss:1.0244 Epoch[89/100] Batch[200/500]
# train loss:0.9198 Epoch[89/100] Batch[250/500]
# train loss:0.8209 Epoch[89/100] Batch[300/500]
# train loss:0.7937 Epoch[89/100] Batch[350/500]
# train loss:0.9663 Epoch[89/100] Batch[400/500]
# train loss:0.9134 Epoch[89/100] Batch[450/500]
# val loss:6.3030 Epoch[89/100]
# val acc:73.0000 Epoch[89/100]
# Epoch[90/100]
# train loss:0.9078 Epoch[90/100] Batch[0/500]
# train loss:0.8704 Epoch[90/100] Batch[50/500]
# train loss:0.8379 Epoch[90/100] Batch[100/500]
# train loss:0.9478 Epoch[90/100] Batch[150/500]
# train loss:0.9065 Epoch[90/100] Batch[200/500]
# train loss:0.8768 Epoch[90/100] Batch[250/500]
# train loss:0.8534 Epoch[90/100] Batch[300/500]
# train loss:0.8113 Epoch[90/100] Batch[350/500]
# train loss:0.9210 Epoch[90/100] Batch[400/500]
# train loss:0.9142 Epoch[90/100] Batch[450/500]
# val loss:5.6410 Epoch[90/100]
# val acc:79.0000 Epoch[90/100]
# Epoch[91/100]
# train loss:0.8329 Epoch[91/100] Batch[0/500]
# train loss:0.8974 Epoch[91/100] Batch[50/500]
# train loss:0.8321 Epoch[91/100] Batch[100/500]
# train loss:0.9049 Epoch[91/100] Batch[150/500]
# train loss:0.9225 Epoch[91/100] Batch[200/500]
# train loss:0.9372 Epoch[91/100] Batch[250/500]
# train loss:0.8803 Epoch[91/100] Batch[300/500]
# train loss:0.9031 Epoch[91/100] Batch[350/500]
# train loss:0.8623 Epoch[91/100] Batch[400/500]
# train loss:0.9515 Epoch[91/100] Batch[450/500]
# val loss:6.2380 Epoch[91/100]
# val acc:79.0000 Epoch[91/100]
# Epoch[92/100]
# train loss:0.8111 Epoch[92/100] Batch[0/500]
# train loss:0.9674 Epoch[92/100] Batch[50/500]
# train loss:0.9305 Epoch[92/100] Batch[100/500]
# train loss:0.8662 Epoch[92/100] Batch[150/500]
# train loss:0.7782 Epoch[92/100] Batch[200/500]
# train loss:0.9388 Epoch[92/100] Batch[250/500]
# train loss:0.8166 Epoch[92/100] Batch[300/500]
# train loss:0.9468 Epoch[92/100] Batch[350/500]
# train loss:0.8456 Epoch[92/100] Batch[400/500]
# train loss:0.8280 Epoch[92/100] Batch[450/500]
# val loss:6.1035 Epoch[92/100]
# val acc:81.0000 Epoch[92/100]
# Epoch[93/100]
# train loss:0.8233 Epoch[93/100] Batch[0/500]
# train loss:0.8649 Epoch[93/100] Batch[50/500]
# train loss:0.9354 Epoch[93/100] Batch[100/500]
# train loss:0.8937 Epoch[93/100] Batch[150/500]
# train loss:0.9657 Epoch[93/100] Batch[200/500]
# train loss:0.8843 Epoch[93/100] Batch[250/500]
# train loss:0.8335 Epoch[93/100] Batch[300/500]
# train loss:1.0017 Epoch[93/100] Batch[350/500]
# train loss:0.9160 Epoch[93/100] Batch[400/500]
# train loss:0.8489 Epoch[93/100] Batch[450/500]
# val loss:5.7760 Epoch[93/100]
# val acc:81.0000 Epoch[93/100]
# Epoch[94/100]
# train loss:0.8490 Epoch[94/100] Batch[0/500]
# train loss:0.9316 Epoch[94/100] Batch[50/500]
# train loss:0.8295 Epoch[94/100] Batch[100/500]
# train loss:0.9045 Epoch[94/100] Batch[150/500]
# train loss:0.8451 Epoch[94/100] Batch[200/500]
# train loss:0.9154 Epoch[94/100] Batch[250/500]
# train loss:0.9762 Epoch[94/100] Batch[300/500]
# train loss:0.8929 Epoch[94/100] Batch[350/500]
# train loss:0.8528 Epoch[94/100] Batch[400/500]
# train loss:0.9092 Epoch[94/100] Batch[450/500]
# val loss:6.3230 Epoch[94/100]
# val acc:81.0000 Epoch[94/100]
# Epoch[95/100]
# train loss:0.9160 Epoch[95/100] Batch[0/500]
# train loss:0.8999 Epoch[95/100] Batch[50/500]
# train loss:0.8027 Epoch[95/100] Batch[100/500]
# train loss:0.8673 Epoch[95/100] Batch[150/500]
# train loss:0.8954 Epoch[95/100] Batch[200/500]
# train loss:0.9378 Epoch[95/100] Batch[250/500]
# train loss:0.9242 Epoch[95/100] Batch[300/500]
# train loss:0.8623 Epoch[95/100] Batch[350/500]
# train loss:0.8882 Epoch[95/100] Batch[400/500]
# train loss:0.9034 Epoch[95/100] Batch[450/500]
# val loss:6.4482 Epoch[95/100]
# val acc:79.0000 Epoch[95/100]
# Epoch[96/100]
# train loss:0.8754 Epoch[96/100] Batch[0/500]
# train loss:0.9404 Epoch[96/100] Batch[50/500]
# train loss:0.9560 Epoch[96/100] Batch[100/500]
# train loss:0.9281 Epoch[96/100] Batch[150/500]
# train loss:0.9003 Epoch[96/100] Batch[200/500]
# train loss:0.9298 Epoch[96/100] Batch[250/500]
# train loss:0.8431 Epoch[96/100] Batch[300/500]
# train loss:0.8840 Epoch[96/100] Batch[350/500]
# train loss:0.8860 Epoch[96/100] Batch[400/500]
# train loss:0.9208 Epoch[96/100] Batch[450/500]
# val loss:6.1350 Epoch[96/100]
# val acc:81.0000 Epoch[96/100]
# Epoch[97/100]
# train loss:0.8754 Epoch[97/100] Batch[0/500]
# train loss:0.8640 Epoch[97/100] Batch[50/500]
# train loss:0.9236 Epoch[97/100] Batch[100/500]
# train loss:0.8127 Epoch[97/100] Batch[150/500]
# train loss:0.8357 Epoch[97/100] Batch[200/500]
# train loss:0.8488 Epoch[97/100] Batch[250/500]
# train loss:0.9161 Epoch[97/100] Batch[300/500]
# train loss:0.8483 Epoch[97/100] Batch[350/500]
# train loss:0.9345 Epoch[97/100] Batch[400/500]
# train loss:0.9205 Epoch[97/100] Batch[450/500]
# val loss:6.4329 Epoch[97/100]
# val acc:85.0000 Epoch[97/100]
# Epoch[98/100]
# train loss:0.8617 Epoch[98/100] Batch[0/500]
# train loss:0.8841 Epoch[98/100] Batch[50/500]
# train loss:0.8680 Epoch[98/100] Batch[100/500]
# train loss:0.8808 Epoch[98/100] Batch[150/500]
# train loss:0.8930 Epoch[98/100] Batch[200/500]
# train loss:0.8428 Epoch[98/100] Batch[250/500]
# train loss:0.8856 Epoch[98/100] Batch[300/500]
# train loss:0.8748 Epoch[98/100] Batch[350/500]
# train loss:0.9063 Epoch[98/100] Batch[400/500]
# train loss:0.8750 Epoch[98/100] Batch[450/500]
# val loss:6.3792 Epoch[98/100]
# val acc:81.0000 Epoch[98/100]
# Epoch[99/100]
# train loss:0.8663 Epoch[99/100] Batch[0/500]
# train loss:0.9381 Epoch[99/100] Batch[50/500]
# train loss:0.9430 Epoch[99/100] Batch[100/500]
# train loss:0.9925 Epoch[99/100] Batch[150/500]
# train loss:0.7736 Epoch[99/100] Batch[200/500]
# train loss:0.8340 Epoch[99/100] Batch[250/500]
# train loss:0.7979 Epoch[99/100] Batch[300/500]
# train loss:0.9058 Epoch[99/100] Batch[350/500]
# train loss:0.8820 Epoch[99/100] Batch[400/500]
# train loss:0.8602 Epoch[99/100] Batch[450/500]
# val loss:6.1460 Epoch[99/100]
# val acc:81.0000 Epoch[99/100]
# Epoch[100/100]
# train loss:0.9079 Epoch[100/100] Batch[0/500]
# train loss:0.9761 Epoch[100/100] Batch[50/500]
# train loss:0.8942 Epoch[100/100] Batch[100/500]
# train loss:0.9110 Epoch[100/100] Batch[150/500]
# train loss:0.9035 Epoch[100/100] Batch[200/500]
# train loss:0.8757 Epoch[100/100] Batch[250/500]
# train loss:0.8511 Epoch[100/100] Batch[300/500]
# train loss:0.8632 Epoch[100/100] Batch[350/500]
# train loss:0.8940 Epoch[100/100] Batch[400/500]
# train loss:0.9675 Epoch[100/100] Batch[450/500]
# val loss:7.3163 Epoch[100/100]
# val acc:79.0000 Epoch[100/100]
# Test Accuracy of the model on the test images: 80.6 %

# %%
utils.show_np_arr(images_mx.cpu()[0])
